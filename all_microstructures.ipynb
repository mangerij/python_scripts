# %%
#Load band gaps and plot them with a panel functionimport osimport subprocessos.chdir('/home/john/projects/ParaView-bin/bin/')subprocess.call('pvpython /media/My\ Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/microstructure-ZnO.py',shell=True)subprocess.call('pvpython /media/My\ Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/microstructure-rTiO2.py',shell=True)subprocess.call('espeak "Your data is harvested."',shell=True)
# Out:
# 0

# %%
#-------------------------------------ZnO-----------------------------------------------------------------------------------## Need 9 different text "mashers" and deleters. We don't want the leftover blank .csvs from lazy ParaView and we want to concatenate all of the nonblank .csvfout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_iso_shell_P0COMP.csv","a")for num in range(0,1): #iso has 1 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_iso_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close() #not really neededfout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_xstl000_shell_P0COMP.csv","a")for num in range(0,12): #xstl000 has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_xstl000_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_xstl111_shell_P0COMP.csv","a")for num in range(0,12): #xst111 has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_xstl111_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_xstl_grain_shell_radial_P0COMP.csv","a")for num in range(0,12): #xst_grain_rad has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_xstl_grain_shell_radial_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_xstl_grain_shell_random_P0COMP.csv","a")for num in range(0,12): #xst_grain_rand has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_xstl_grain_shell_random_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_Fcore_xstl000_shell_P0COMP.csv","a")for num in range(0,16): #xst000_fcore has 15 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_Fcore_xstl000_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_Fcore_xstl111_shell_P0COMP.csv","a")for num in range(0,16): #xst111_fcore has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_Fcore_xstl111_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_Fcore_xstl_grain_shell_radial_P0COMP.csv","a")for num in range(0,16): #xst111_fcore has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_Fcore_xstl_grain_shell_radial_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_Fcore_xstl_grain_shell_random_P0COMP.csv","a")for num in range(0,16): #xst111_fcore has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_Fcore_xstl_grain_shell_random_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()#-------------------------------------rTiO2-----------------------------------------------------------------------------------## Need 9 different text "mashers" and deleters. We don't want the leftover blank .csvs from lazy ParaView and we want to concatenate all of the nonblank .csvfout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_iso_shell_P0COMP.csv","a")for num in range(0,1): #iso has 1 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_iso_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close() #not really neededfout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_xstl000_shell_P0COMP.csv","a")for num in range(0,12): #xstl000 has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_xstl000_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_xstl111_shell_P0COMP.csv","a")for num in range(0,12): #xst111 has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_xstl111_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_xstl_grain_shell_radial_P0COMP.csv","a")for num in range(0,12): #xst_grain_rad has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_xstl_grain_shell_radial_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_xstl_grain_shell_random_P0COMP.csv","a")for num in range(0,12): #xst_grain_rand has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_xstl_grain_shell_random_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl000_shell_P0COMP.csv","a")for num in range(0,16): #xst000_fcore has 15 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl000_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl111_shell_P0COMP.csv","a")for num in range(0,16): #xst111_fcore has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl111_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl_grain_shell_radial_P0COMP.csv","a")for num in range(0,16): #xst111_fcore has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl_grain_shell_radial_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl_grain_shell_random_P0COMP.csv","a")for num in range(0,16): #xst111_fcore has 12 csv    f = open("/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl_grain_shell_random_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()

# %%
#numpy genfromtxt crashes when loading large files, have to use an iterative loading schemeimport numpy as npdef iter_loadtxt(filename, delimiter=',', skiprows=1, dtype=float):    def iter_func():        with open(filename, 'r') as infile:            for _ in range(skiprows):                next(infile)            for line in infile:                line = line.rstrip().split(delimiter)                for item in line:                    yield dtype(item)        iter_loadtxt.rowlength = len(line)    data = np.fromiter(iter_func(), dtype=dtype)    data = data.reshape((-1, iter_loadtxt.rowlength))    return data

# %%
import matplotlib.pyplot as pltimport pylabfrom matplotlib import rc#ZnZnO_xstl000_core_iso_shell_data_EgVolume data0 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_iso_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_core_xstl000_shell_data_EgVolume data1 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_xstl000_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_core_xstl111_shell_data_EgVolume data2 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_xstl111_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_core_xstl_rad_shell_data_EgVolume data3 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_xstl_grain_shell_radial_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_core_xstl_rand_shell_data_EgVolume data4 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_core_xstl_grain_shell_random_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#facet#ZnZnO_xstl000_Fcore_xstl000_data_EgVolume data5 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_Fcore_xstl000_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_Fcore_xstl111_data_EgVolume data6 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_Fcore_xstl111_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_Fcore_xstl_rad_shell_data_EgVolume data7 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_Fcore_xstl_grain_shell_radial_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_Fcore_xstl_rand_shell_data_EgVolume data8 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_Zn_ZnO_xstl000_Fcore_xstl_grain_shell_random_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_core_iso_shell_data_EgVolume data9 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_iso_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_core_xstl000_shell_data_EgVolume data10 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_xstl000_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_core_xstl111_shell_data_EgVolume data11 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_xstl111_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_core_xstl_rad_shell_data_EgVolume data12 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_xstl_grain_shell_radial_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_core_xstl_rand_shell_data_EgVolume data13 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_core_xstl_grain_shell_random_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#facet#ZnOrTiO2_xstl000_Fcore_xstl000_shell_data_EgVolume data14 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl000_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_Fcore_xstl111_shell_data_EgVolume data15 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl111_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_Fcore_xstl_rad_shell_data_EgVolume data16 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl_grain_shell_radial_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_Fcore_xstl_rand_shell_data_EgVolume data17 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl_grain_shell_random_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)

# %%
#------Load Variables from the csv------#vol0 = [row[12] for row in data0] vol1 = [row[12] for row in data1]vol2 = [row[12] for row in data2] vol3 = [row[12] for row in data3]vol4 = [row[12] for row in data4]vol5 = [row[12] for row in data5] vol6 = [row[12] for row in data6] vol7 = [row[12] for row in data7]vol8 = [row[12] for row in data8]vol9 = [row[12] for row in data9]vol10 = [row[12] for row in data10]vol11 = [row[12] for row in data11]vol12 = [row[12] for row in data12]vol13 = [row[12] for row in data13]vol14 = [row[12] for row in data14]vol15 = [row[12] for row in data15]vol16 = [row[12] for row in data16]vol17 = [row[12] for row in data17]Eg0 = [row[8] for row in data0] Eg1 = [row[8] for row in data1]Eg2 = [row[8] for row in data2] Eg3 = [row[8] for row in data3]Eg4 = [row[8] for row in data4]Eg5 = [row[8] for row in data5] Eg6 = [row[8] for row in data6] Eg7 = [row[8] for row in data7]Eg8 = [row[8] for row in data8]Eg9 = [row[8] for row in data9]Eg10 = [row[8] for row in data10]Eg11 = [row[8] for row in data11]Eg12 = [row[8] for row in data12]Eg13 = [row[8] for row in data13]Eg14 = [row[8] for row in data14]Eg15 = [row[8] for row in data15]Eg16 = [row[8] for row in data16]Eg17 = [row[8] for row in data17]nbins = 400#comment on nbins, if nbins > ideal, then we get "dips" in the spectrum#                  if nbins < ideal, then we get "peaks" in the spectrum#   ideal = ideal(Precision) in microstructures.py filentwk1 = 580ntwk2 = 50Hbg0, xedgesbg0, yedgesbg0 = np.histogram2d(Eg0[1:len(Eg0)],vol0[1:len(vol0)],bins=nbins)Hbg1, xedgesbg1, yedgesbg1 = np.histogram2d(Eg1[1:len(Eg1)],vol1[1:len(vol1)],bins=nbins)Hbg2, xedgesbg2, yedgesbg2 = np.histogram2d(Eg2[1:len(Eg2)],vol2[1:len(vol2)],bins=nbins)Hbg3, xedgesbg3, yedgesbg3 = np.histogram2d(Eg3[1:len(Eg3)],vol3[1:len(vol3)],bins=nbins)Hbg4, xedgesbg4, yedgesbg4 = np.histogram2d(Eg4[1:len(Eg4)],vol4[1:len(vol4)],bins=nbins)Hbg5, xedgesbg5, yedgesbg5 = np.histogram2d(Eg5[1:len(Eg5)],vol5[1:len(vol5)],bins=nbins)Hbg6, xedgesbg6, yedgesbg6 = np.histogram2d(Eg6[1:len(Eg6)],vol6[1:len(vol6)],bins=nbins)Hbg7, xedgesbg7, yedgesbg7 = np.histogram2d(Eg7[1:len(Eg7)],vol7[1:len(vol7)],bins=nbins)Hbg8, xedgesbg8, yedgesbg8 = np.histogram2d(Eg8[1:len(Eg8)],vol8[1:len(vol8)],bins=nbins)Hbg9, xedgesbg9, yedgesbg9 = np.histogram2d(Eg9[1:len(Eg9)],vol9[1:len(vol9)],bins=nbins)Hbg10, xedgesbg10, yedgesbg10 = np.histogram2d(Eg10[1:len(Eg10)],vol10[1:len(vol10)],bins=nbins)Hbg11, xedgesbg11, yedgesbg11 = np.histogram2d(Eg11[1:len(Eg11)],vol11[1:len(vol11)],bins=nbins)Hbg12, xedgesbg12, yedgesbg12 = np.histogram2d(Eg12[1:len(Eg12)],vol12[1:len(vol12)],bins=nbins)Hbg13, xedgesbg13, yedgesbg13 = np.histogram2d(Eg13[1:len(Eg13)],vol13[1:len(vol13)],bins=nbins)Hbg14, xedgesbg14, yedgesbg14 = np.histogram2d(Eg14[1:len(Eg14)],vol14[1:len(vol14)],bins=nbins)Hbg15, xedgesbg15, yedgesbg15 = np.histogram2d(Eg15[1:len(Eg15)],vol15[1:len(vol15)],bins=nbins)Hbg16, xedgesbg16, yedgesbg16 = np.histogram2d(Eg16[1:len(Eg16)],vol16[1:len(vol16)],bins=nbins)Hbg17, xedgesbg17, yedgesbg17 = np.histogram2d(Eg17[1:len(Eg17)],vol17[1:len(vol17)],bins=nbins)Hbg0 = np.rot90(Hbg0)Hbg0 = np.flipud(Hbg0)Hbg1 = np.rot90(Hbg1)Hbg1 = np.flipud(Hbg1)Hbg2 = np.rot90(Hbg2)Hbg2 = np.flipud(Hbg2)Hbg3 = np.rot90(Hbg3)Hbg3 = np.flipud(Hbg3)Hbg4 = np.rot90(Hbg4)Hbg4 = np.flipud(Hbg4)Hbg5 = np.rot90(Hbg5)Hbg5 = np.flipud(Hbg5)Hbg6 = np.rot90(Hbg6)Hbg6 = np.flipud(Hbg6)Hbg7 = np.rot90(Hbg7)Hbg7 = np.flipud(Hbg7)Hbg8 = np.rot90(Hbg8)Hbg8 = np.flipud(Hbg8)Hbg9 = np.rot90(Hbg9)Hbg9 = np.flipud(Hbg9)Hbg10 = np.rot90(Hbg10)Hbg10 = np.flipud(Hbg10)Hbg11 = np.rot90(Hbg11)Hbg11 = np.flipud(Hbg11)Hbg12 = np.rot90(Hbg12)Hbg12 = np.flipud(Hbg12)Hbg13 = np.rot90(Hbg13)Hbg13 = np.flipud(Hbg13)Hbg14 = np.rot90(Hbg14)Hbg14 = np.flipud(Hbg14)Hbg15 = np.rot90(Hbg15)Hbg15 = np.flipud(Hbg15)Hbg16 = np.rot90(Hbg16)Hbg16 = np.flipud(Hbg16)Hbg17 = np.rot90(Hbg17)Hbg17 = np.flipud(Hbg17)yedgesbg_up0 = yedgesbg0[0:len(yedgesbg0)-1]+(yedgesbg0[1:len(yedgesbg0)]-yedgesbg0[0:len(yedgesbg0)-1])/2yedgesbg_up1 = yedgesbg1[0:len(yedgesbg1)-1]+(yedgesbg1[1:len(yedgesbg1)]-yedgesbg1[0:len(yedgesbg1)-1])/2yedgesbg_up2 = yedgesbg2[0:len(yedgesbg2)-1]+(yedgesbg2[1:len(yedgesbg2)]-yedgesbg2[0:len(yedgesbg2)-1])/2yedgesbg_up3 = yedgesbg3[0:len(yedgesbg3)-1]+(yedgesbg3[1:len(yedgesbg3)]-yedgesbg3[0:len(yedgesbg3)-1])/2yedgesbg_up4 = yedgesbg4[0:len(yedgesbg4)-1]+(yedgesbg4[1:len(yedgesbg4)]-yedgesbg4[0:len(yedgesbg4)-1])/2yedgesbg_up5 = yedgesbg5[0:len(yedgesbg5)-1]+(yedgesbg5[1:len(yedgesbg5)]-yedgesbg5[0:len(yedgesbg5)-1])/2yedgesbg_up6 = yedgesbg6[0:len(yedgesbg6)-1]+(yedgesbg6[1:len(yedgesbg6)]-yedgesbg6[0:len(yedgesbg6)-1])/2yedgesbg_up7 = yedgesbg7[0:len(yedgesbg7)-1]+(yedgesbg7[1:len(yedgesbg7)]-yedgesbg7[0:len(yedgesbg7)-1])/2yedgesbg_up8 = yedgesbg8[0:len(yedgesbg8)-1]+(yedgesbg8[1:len(yedgesbg8)]-yedgesbg8[0:len(yedgesbg8)-1])/2yedgesbg_up9 = yedgesbg9[0:len(yedgesbg9)-1]+(yedgesbg9[1:len(yedgesbg9)]-yedgesbg9[0:len(yedgesbg9)-1])/2yedgesbg_up10 = yedgesbg10[0:len(yedgesbg10)-1]+(yedgesbg10[1:len(yedgesbg10)]-yedgesbg10[0:len(yedgesbg10)-1])/2yedgesbg_up11 = yedgesbg11[0:len(yedgesbg11)-1]+(yedgesbg11[1:len(yedgesbg11)]-yedgesbg11[0:len(yedgesbg11)-1])/2yedgesbg_up12 = yedgesbg12[0:len(yedgesbg12)-1]+(yedgesbg12[1:len(yedgesbg12)]-yedgesbg12[0:len(yedgesbg12)-1])/2yedgesbg_up13 = yedgesbg13[0:len(yedgesbg13)-1]+(yedgesbg13[1:len(yedgesbg13)]-yedgesbg13[0:len(yedgesbg13)-1])/2yedgesbg_up14 = yedgesbg14[0:len(yedgesbg14)-1]+(yedgesbg14[1:len(yedgesbg14)]-yedgesbg14[0:len(yedgesbg14)-1])/2yedgesbg_up15 = yedgesbg15[0:len(yedgesbg15)-1]+(yedgesbg15[1:len(yedgesbg15)]-yedgesbg15[0:len(yedgesbg15)-1])/2yedgesbg_up16 = yedgesbg16[0:len(yedgesbg16)-1]+(yedgesbg16[1:len(yedgesbg16)]-yedgesbg16[0:len(yedgesbg16)-1])/2yedgesbg_up17 = yedgesbg17[0:len(yedgesbg17)-1]+(yedgesbg17[1:len(yedgesbg17)]-yedgesbg17[0:len(yedgesbg17)-1])/2vbg0j = np.einsum('ij,i',Hbg0,yedgesbg_up0)vbg1j = np.einsum('ij,i',Hbg1,yedgesbg_up1)vbg2j = np.einsum('ij,i',Hbg2,yedgesbg_up2)vbg3j = np.einsum('ij,i',Hbg3,yedgesbg_up3)vbg4j = np.einsum('ij,i',Hbg4,yedgesbg_up4)vbg5j = np.einsum('ij,i',Hbg5,yedgesbg_up5)vbg6j = np.einsum('ij,i',Hbg6,yedgesbg_up6)vbg7j = np.einsum('ij,i',Hbg7,yedgesbg_up7)vbg8j = np.einsum('ij,i',Hbg8,yedgesbg_up8)vbg9j = np.einsum('ij,i',Hbg9,yedgesbg_up9)vbg10j = np.einsum('ij,i',Hbg10,yedgesbg_up10)vbg11j = np.einsum('ij,i',Hbg11,yedgesbg_up11)vbg12j = np.einsum('ij,i',Hbg12,yedgesbg_up12)vbg13j = np.einsum('ij,i',Hbg13,yedgesbg_up13)vbg14j = np.einsum('ij,i',Hbg14,yedgesbg_up14)vbg15j = np.einsum('ij,i',Hbg15,yedgesbg_up15)vbg16j = np.einsum('ij,i',Hbg16,yedgesbg_up16)vbg17j = np.einsum('ij,i',Hbg17,yedgesbg_up17)Vbg0j = vbg0j/sum(vbg0j)*100Vbg1j = vbg1j/sum(vbg1j)*100Vbg2j = vbg2j/sum(vbg2j)*100Vbg3j = vbg3j/sum(vbg3j)*100Vbg4j = vbg4j/sum(vbg4j)*100Vbg5j = vbg5j/sum(vbg5j)*100Vbg6j = vbg6j/sum(vbg6j)*100Vbg7j = vbg7j/sum(vbg7j)*100Vbg8j = vbg8j/sum(vbg8j)*100Vbg9j = vbg9j/sum(vbg9j)*100Vbg10j = vbg10j/sum(vbg10j)*100Vbg11j = vbg11j/sum(vbg11j)*100Vbg12j = vbg12j/sum(vbg12j)*100Vbg13j = vbg13j/sum(vbg13j)*100Vbg14j = vbg14j/sum(vbg14j)*100Vbg15j = vbg15j/sum(vbg15j)*100Vbg16j = vbg16j/sum(vbg16j)*100Vbg17j = vbg17j/sum(vbg17j)*100x_bg0 = xedgesbg0[0:len(xedgesbg0)-1]+(xedgesbg0[1:len(xedgesbg0)]-xedgesbg0[0:len(xedgesbg0)-1])/2x_bg1 = xedgesbg1[0:len(xedgesbg1)-1]+(xedgesbg1[1:len(xedgesbg1)]-xedgesbg1[0:len(xedgesbg1)-1])/2x_bg2 = xedgesbg2[0:len(xedgesbg2)-1]+(xedgesbg2[1:len(xedgesbg2)]-xedgesbg2[0:len(xedgesbg2)-1])/2x_bg3 = xedgesbg3[0:len(xedgesbg3)-1]+(xedgesbg3[1:len(xedgesbg3)]-xedgesbg3[0:len(xedgesbg3)-1])/2x_bg4 = xedgesbg4[0:len(xedgesbg4)-1]+(xedgesbg4[1:len(xedgesbg4)]-xedgesbg4[0:len(xedgesbg4)-1])/2x_bg5 = xedgesbg5[0:len(xedgesbg5)-1]+(xedgesbg5[1:len(xedgesbg5)]-xedgesbg5[0:len(xedgesbg5)-1])/2x_bg6 = xedgesbg6[0:len(xedgesbg6)-1]+(xedgesbg6[1:len(xedgesbg6)]-xedgesbg6[0:len(xedgesbg6)-1])/2x_bg7 = xedgesbg7[0:len(xedgesbg7)-1]+(xedgesbg7[1:len(xedgesbg7)]-xedgesbg7[0:len(xedgesbg7)-1])/2x_bg8 = xedgesbg8[0:len(xedgesbg8)-1]+(xedgesbg8[1:len(xedgesbg8)]-xedgesbg8[0:len(xedgesbg8)-1])/2x_bg9 = xedgesbg9[0:len(xedgesbg9)-1]+(xedgesbg9[1:len(xedgesbg9)]-xedgesbg9[0:len(xedgesbg9)-1])/2x_bg10 = xedgesbg10[0:len(xedgesbg10)-1]+(xedgesbg10[1:len(xedgesbg10)]-xedgesbg10[0:len(xedgesbg10)-1])/2x_bg11 = xedgesbg11[0:len(xedgesbg11)-1]+(xedgesbg11[1:len(xedgesbg11)]-xedgesbg11[0:len(xedgesbg11)-1])/2x_bg12 = xedgesbg12[0:len(xedgesbg12)-1]+(xedgesbg12[1:len(xedgesbg12)]-xedgesbg12[0:len(xedgesbg12)-1])/2x_bg13 = xedgesbg13[0:len(xedgesbg13)-1]+(xedgesbg13[1:len(xedgesbg13)]-xedgesbg13[0:len(xedgesbg13)-1])/2x_bg14 = xedgesbg14[0:len(xedgesbg14)-1]+(xedgesbg14[1:len(xedgesbg14)]-xedgesbg14[0:len(xedgesbg14)-1])/2x_bg15 = xedgesbg15[0:len(xedgesbg15)-1]+(xedgesbg15[1:len(xedgesbg15)]-xedgesbg15[0:len(xedgesbg15)-1])/2x_bg16 = xedgesbg16[0:len(xedgesbg16)-1]+(xedgesbg16[1:len(xedgesbg16)]-xedgesbg16[0:len(xedgesbg16)-1])/2x_bg17 = xedgesbg17[0:len(xedgesbg17)-1]+(xedgesbg17[1:len(xedgesbg17)]-xedgesbg17[0:len(xedgesbg17)-1])/2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/john/<ipython-input-35-f9f69e7679e2> in <module>()
#      56
#      57 Hbg0, xedgesbg0, yedgesbg0 = np.histogram2d(Eg0[1:len(Eg0)],vol0[1:len(vol0)],bins=nbins)
# ---> 58 Hbg1, xedgesbg1, yedgesbg1 = np.histogram2d(Eg0[1:len(Eg1)],vol1[1:len(vol1)],bins=nbins)
#      59 Hbg2, xedgesbg2, yedgesbg2 = np.histogram2d(Eg0[1:len(Eg2)],vol2[1:len(vol2)],bins=nbins)
#      60 Hbg3, xedgesbg3, yedgesbg3 = np.histogram2d(Eg0[1:len(Eg3)],vol3[1:len(vol3)],bins=nbins)
#
# /usr/lib/python2.7/dist-packages/numpy/lib/twodim_base.pyc in histogram2d(x, y, bins, range, normed, weights)
#     613         xedges = yedges = asarray(bins, float)
#     614         bins = [xedges, yedges]
# --> 615     hist, edges = histogramdd([x,y], bins, range, normed, weights)
#     616     return hist, edges[0], edges[1]
#     617
#
# ...

# %%
import numpy as npimport matplotlib.pyplot as pltfrom matplotlib import rcplt.plot(x_bg0,Vbg0j,'b.',linewidth=3.5, label = 'Isotropic')plt.plot(x_bg1,Vbg1j,'r.',linewidth=3.5, label = '[000]')plt.plot(x_bg2,Vbg2j,'g.',linewidth=3.5, label = '[111]')plt.plot(x_bg3,Vbg3j,'b*',linewidth=3.5, label = 'Radial')plt.plot(x_bg4,Vbg4j,'k.',linewidth=3.5, label = 'Random')plt.xlim([3.13,3.16])#plt.legend(labelspacing = 1.0,loc=1,prop={'size':16})#Custom PlotLabels for differing fontsize in same xlabel#plt.rc('text',usetex=True)#plt.text(2.2,-.5,'$\sigma_{jj}$',fontsize=30)#plt.text(2.5,-.5,'[$\,\,10^{-10}\, \mathrm{N}/\mathrm{nm}^2$]',fontsize = 20)###all four of the of these plots are 25 nm total diameter, 15 nm core diameter#plt.xlabel('$\delta E \,10^{-2}\, [\mathrm{eV}]$',fontsize = 24)plt.tick_params(axis='both', which='major', labelsize=22)tick_vals = np.linspace(0,9,10)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = ''tick_labels[1] = '1'tick_labels[2] = '2'tick_labels[3] = '3'tick_labels[4] = '4'tick_labels[5] = '5'tick_labels[6] = '6'tick_labels[7] = '7'tick_labels[8] = '8'tick_labels[9] = '9'plt.yticks(tick_vals, tick_labels)tick_vals = np.linspace(3.13,3.16,4)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = '-7'tick_labels[1] = '-6'tick_labels[2] = '-5'tick_labels[3] = '-4'plt.xticks(tick_vals, tick_labels)plt.ylabel('Shell volume fraction [$\%$]',fontsize =20)plt.savefig("/home/john/microstructure_Zn_ZnO_Eg_hist_sph_bins.eps",format='eps',dpi=1200,bbox_inches='tight')plt.show()

# %%
import numpy as npimport matplotlib.pyplot as pltfrom matplotlib import rcplt.plot(x_bg5,Vbg5j,'r',linewidth=3.5, label = '[000]')plt.plot(x_bg6,Vbg6j,'g',linewidth=3.5, label = '[111]')plt.plot(x_bg7,Vbg7j,'b--',linewidth=3.5, label = 'Radial')plt.plot(x_bg8,Vbg8j,'k-.',linewidth=3.5, label = 'Random')plt.xlim([3.13,3.16])#plt.legend(labelspacing = 1.0,loc=1,prop={'size':16})#Custom PlotLabels for differing fontsize in same xlabel#plt.rc('text',usetex=True)#plt.text(2.2,-.5,'$\sigma_{jj}$',fontsize=30)#plt.text(2.5,-.5,'[$\,\,10^{-10}\, \mathrm{N}/\mathrm{nm}^2$]',fontsize = 20)###all four of the of these plots are 25 nm total diameter, 15 nm core diameterplt.xlabel('$\delta E \,10^{-2}\, [\mathrm{eV}]$',fontsize = 24)plt.tick_params(axis='both', which='major', labelsize=22)tick_vals = np.linspace(0,9,10)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = ''tick_labels[1] = '1'tick_labels[2] = '2'tick_labels[3] = '3'tick_labels[4] = '4'tick_labels[5] = '5'tick_labels[6] = '6'tick_labels[7] = '7'tick_labels[8] = '8'tick_labels[9] = '9'plt.yticks(tick_vals, tick_labels)tick_vals = np.linspace(3.13,3.16,4)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = '-7'tick_labels[1] = '-6'tick_labels[2] = '-5'tick_labels[3] = '-4'plt.xticks(tick_vals, tick_labels)plt.ylabel('Shell volume fraction [$\%$]',fontsize =20)plt.savefig("/home/john/microstructure_Zn_ZnO_Eg_hist_fac_bins.eps",format='eps',dpi=1200,bbox_inches='tight')plt.show()

# %%
import numpy as npimport matplotlib.pyplot as pltfrom matplotlib import rcplt.plot(x_bg9,Vbg9j,'b.',linewidth=3.5, label = 'Isotropic')plt.plot(x_bg10,Vbg10j,'r.',linewidth=3.5, label = '[000]')plt.plot(x_bg11,Vbg11j,'g.',linewidth=3.5, label = '[111]')plt.plot(x_bg12,Vbg12j,'b*',linewidth=3.5, label = 'Radial')plt.plot(x_bg13,Vbg13j,'k.',linewidth=3.5, label = 'Random')plt.xlim([3.0192,3.0202])plt.legend(labelspacing = 1.0,loc=1,prop={'size':16})#Custom PlotLabels for differing fontsize in same xlabel#plt.rc('text',usetex=True)#plt.text(2.2,-.5,'$\sigma_{jj}$',fontsize=30)#plt.text(2.5,-.5,'[$\,\,10^{-10}\, \mathrm{N}/\mathrm{nm}^2$]',fontsize = 20)###all four of the of these plots are 25 nm total diameter, 15 nm core diameter#plt.xlabel('$\delta E \,10^{-4}\, [\mathrm{eV}]$',fontsize = 24)plt.tick_params(axis='both', which='major', labelsize=22)tick_vals = np.linspace(0,9,10)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = ''tick_labels[1] = '1'tick_labels[2] = '2'tick_labels[3] = '3'tick_labels[4] = '4'tick_labels[5] = '5'tick_labels[6] = '6'tick_labels[7] = '7'tick_labels[8] = '8'tick_labels[9] = '9'plt.yticks(tick_vals, tick_labels)#8 5 1 +2tick_vals = np.linspace(3.0192,3.0202,4)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = '-8'tick_labels[1] = '-5'tick_labels[2] = '-1'tick_labels[3] = '+2'plt.xticks(tick_vals, tick_labels)#plt.ylabel('Shell volume fraction [$\%$]',fontsize =20)plt.savefig("/home/john/microstructure_ZnO_rTiO2_Eg_hist_sph_bins.eps",format='eps',dpi=1200,bbox_inches='tight')plt.show()

# %%
import numpy as npimport matplotlib.pyplot as pltfrom matplotlib import rcplt.xlim([3.0193,3.0201])plt.plot(x_bg14,Vbg14j,'r.',linewidth=3.5, label = '[000]')plt.plot(x_bg15,Vbg15j,'g.',linewidth=3.5, label = '[111]')plt.plot(x_bg16,Vbg16j,'b--',linewidth=3.5, label = 'Radial')plt.plot(x_bg17,Vbg17j,'k-.',linewidth=3.5, label = 'Random')#plt.legend(labelspacing = 1.0,loc=1,prop={'size':16})#Custom PlotLabels for differing fontsize in same xlabel#plt.rc('text',usetex=True)#plt.text(2.2,-.5,'$\sigma_{jj}$',fontsize=30)#plt.text(2.5,-.5,'[$\,\,10^{-10}\, \mathrm{N}/\mathrm{nm}^2$]',fontsize = 20)###all four of the of these plots are 25 nm total diameter, 15 nm core diameterplt.xlabel('$\delta E \,10^{-4}\, [\mathrm{eV}]$',fontsize = 24)plt.tick_params(axis='both', which='major', labelsize=22)tick_vals = np.linspace(0,9,10)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = ''tick_labels[1] = '1'tick_labels[2] = '2'tick_labels[3] = '3'tick_labels[4] = '4'tick_labels[5] = '5'tick_labels[6] = '6'tick_labels[7] = '7'tick_labels[8] = '8' tick_labels[9] = '9'plt.yticks(tick_vals, tick_labels)tick_vals = np.linspace(3.0192,3.0202,4)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = '-8'tick_labels[1] = '-5'tick_labels[2] = '-1'tick_labels[3] = '+2'plt.xticks(tick_vals, tick_labels)#plt.ylabel('Shell volume fraction [$\%$]',fontsize =20)plt.savefig("/home/john/microstructure_ZnO_rTiO2_Eg_hist_fac.eps",format='eps',dpi=1200,bbox_inches='tight')plt.show()

# %%
#run a bash script here with the following# subprocess.call(' inkscape --export-png=/home/john/newfile.png /home/john/file.svg')#this will vectorize the file.# Thanks to http://neuroscience.telenczuk.pl/?p=331 [Baros Telenczuk]import subprocesssubprocess.call('inkscape --export-png=/home/john/projects/calculations/core_shell/microstructure_Zn_ZnO_Eg_hist_sph.png /home/john/projects/calculations/core_shell/microstructure_Zn_ZnO_Eg_hist_sph.svg',shell=True)subprocess.call('inkscape --export-png=/home/john/projects/calculations/core_shell/microstructure_Zn_ZnO_Eg_hist_fac.png /home/john/projects/calculations/core_shell/microstructure_Zn_ZnO_Eg_hist_fac.svg',shell=True)subprocess.call('inkscape --export-png=/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph.png /home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph.svg',shell=True)subprocess.call('inkscape --export-png=/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_fac.png /home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_fac.svg',shell=True)
# Out:
# 0

# %%
import matplotlib.pyplot as pltimport matplotlib.image as mpimgimport numpy as npfig, ax = plt.subplots(2,2)img1 =mpimg.imread('/home/john/projects/calculations/core_shell/microstructure_Zn_ZnO_Eg_hist_sph.png')img2 =mpimg.imread('/home/john/projects/calculations/core_shell/microstructure_Zn_ZnO_Eg_hist_fac.png')img3 =mpimg.imread('/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph.png')img4 =mpimg.imread('/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_fac.png')imgplot = ax[0,0].imshow(img1)ax[0,0].set_axis_off()ax[0,0].text(100,100,'$\,\mathrm{A}\,$',fontsize=15)imgplot = ax[0,1].imshow(img2) #origin = 'lower' flag in imshow() flips the imageax[0,1].set_axis_off()ax[0,1].text(100,100,'$\,\mathrm{B}\,$',fontsize=15)imgplot = ax[1,0].imshow(img3,origin='upper')ax[1,0].set_axis_off()ax[1,0].text(100,100,'$\,\mathrm{C}\,$',fontsize=15)imgplot = ax[1,1].imshow(img4,origin='upper') ax[1,1].set_axis_off()ax[1,1].text(100,100,'$\,\mathrm{D}\,$',fontsize=15)plt.gca().set_axis_off()plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0,             hspace = 0, wspace = 0)plt.margins(0,0)plt.tight_layoutplt.savefig('/home/john/projects/calculations/core_shell/microstruct16-3-scale.eps',format='eps',dpi=250, rasterized=True,bbox_inches = 'tight')plt.show()

# %% [markdown]
# Let's investigate the ZnO core now.

# %%
#Load band gaps and plot them with a panel functionimport osimport subprocessos.chdir('/home/john/projects/ParaView-bin/bin/')subprocess.call('pvpython /media/My\ Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/microstructure-rTiO2_core.py',shell=True)subprocess.call('espeak "Your data is harvested."',shell=True)
# Out:
# 0

# %%
#deleted the "mashing" script since we only have one csv file here.

# %%
import matplotlib.pyplot as pltimport pylabfrom matplotlib import rcimport numpy as np#numpy genfromtxt crashes when loading large files, have to use an iterative loading schemedef iter_loadtxt(filename, delimiter=',', skiprows=1, dtype=float):    def iter_func():        with open(filename, 'r') as infile:            for _ in range(skiprows):                next(infile)            for line in infile:                line = line.rstrip().split(delimiter)                for item in line:                    yield dtype(item)        iter_loadtxt.rowlength = len(line)    data = np.fromiter(iter_func(), dtype=dtype)    data = data.reshape((-1, iter_loadtxt.rowlength))    return data#ZnOrTiO2_xstl000_core_iso_shell_data_EgVolume data9 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/test/fsetout_ZnO_rTiO2_xstl000_core_iso_P0-1.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_core_xstl000_shell_data_EgVolume data10 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/test/fsetout_ZnO_rTiO2_xstl000_core_xstl000_P0-12.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_core_xstl111_shell_data_EgVolume data11 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/test/fsetout_ZnO_rTiO2_xstl000_core_xstl111_P0-12.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_core_xstl_rad_shell_data_EgVolume data12 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/test/fsetout_ZnO_rTiO2_xstl000_core_xstl_grain_radial_P0-12.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_core_xstl_rand_shell_data_EgVolume data13 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/test/fsetout_ZnO_rTiO2_xstl000_core_xstl_grain_random_P0-12.csv',delimiter=',',skiprows=1,dtype=float)#facet#ZnOrTiO2_xstl000_Fcore_xstl000_shell_data_EgVolume data14 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/test/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl000_P0-15.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_Fcore_xstl111_shell_data_EgVolume data15 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/test/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl111_P0-15.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_Fcore_xstl_rad_shell_data_EgVolume data16 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/test/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl_grain_radial_P0-15.csv',delimiter=',',skiprows=1,dtype=float)#ZnOrTiO2_xstl000_Fcore_xstl_rand_shell_data_EgVolume data17 = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/all_microstructures_final/test/fsetout_ZnO_rTiO2_xstl000_Fcore_xstl_grain_random_P0-15.csv',delimiter=',',skiprows=1,dtype=float)

# %%
#------Load Variables from the csv------#vol9 = [row[12] for row in data9]vol10 = [row[12] for row in data10]vol11 = [row[12] for row in data11]vol12 = [row[12] for row in data12]vol13 = [row[12] for row in data13]vol14 = [row[12] for row in data14]vol15 = [row[12] for row in data15]vol16 = [row[12] for row in data16]vol17 = [row[12] for row in data17]Eg9 = [row[8] for row in data9]Eg10 = [row[8] for row in data10]Eg11 = [row[8] for row in data11]Eg12 = [row[8] for row in data12]Eg13 = [row[8] for row in data13]Eg14 = [row[8] for row in data14]Eg15 = [row[8] for row in data15]Eg16 = [row[8] for row in data16]Eg17 = [row[8] for row in data17]nbins = 150#comment on nbins, if nbins > ideal, then we get "dips" in the spectrum#                  if nbins < ideal, then we get "peaks" in the spectrum#   ideal = ideal(Precision) in microstructures.py fileHbg9, xedgesbg9, yedgesbg9 = np.histogram2d(Eg9[1:len(Eg9)],vol9[1:len(vol9)],bins=nbins)Hbg10, xedgesbg10, yedgesbg10 = np.histogram2d(Eg10[1:len(Eg10)],vol10[1:len(vol10)],bins=nbins)Hbg11, xedgesbg11, yedgesbg11 = np.histogram2d(Eg11[1:len(Eg11)],vol11[1:len(vol11)],bins=nbins)Hbg12, xedgesbg12, yedgesbg12 = np.histogram2d(Eg12[1:len(Eg12)],vol12[1:len(vol12)],bins=nbins)Hbg13, xedgesbg13, yedgesbg13 = np.histogram2d(Eg13[1:len(Eg13)],vol13[1:len(vol13)],bins=nbins)Hbg14, xedgesbg14, yedgesbg14 = np.histogram2d(Eg14[1:len(Eg14)],vol14[1:len(vol14)],bins=nbins)Hbg15, xedgesbg15, yedgesbg15 = np.histogram2d(Eg15[1:len(Eg15)],vol15[1:len(vol15)],bins=nbins)Hbg16, xedgesbg16, yedgesbg16 = np.histogram2d(Eg16[1:len(Eg16)],vol16[1:len(vol16)],bins=nbins)Hbg17, xedgesbg17, yedgesbg17 = np.histogram2d(Eg17[1:len(Eg17)],vol17[1:len(vol17)],bins=nbins)Hbg9 = np.rot90(Hbg9)Hbg9 = np.flipud(Hbg9)Hbg10 = np.rot90(Hbg10)Hbg10 = np.flipud(Hbg10)Hbg11 = np.rot90(Hbg11)Hbg11 = np.flipud(Hbg11)Hbg12 = np.rot90(Hbg12)Hbg12 = np.flipud(Hbg12)Hbg13 = np.rot90(Hbg13)Hbg13 = np.flipud(Hbg13)Hbg14 = np.rot90(Hbg14)Hbg14 = np.flipud(Hbg14)Hbg15 = np.rot90(Hbg15)Hbg15 = np.flipud(Hbg15)Hbg16 = np.rot90(Hbg16)Hbg16 = np.flipud(Hbg16)Hbg17 = np.rot90(Hbg17)Hbg17 = np.flipud(Hbg17)yedgesbg_up9 = yedgesbg9[0:len(yedgesbg9)-1]+(yedgesbg9[1:len(yedgesbg9)]-yedgesbg9[0:len(yedgesbg9)-1])/2yedgesbg_up10 = yedgesbg10[0:len(yedgesbg10)-1]+(yedgesbg10[1:len(yedgesbg10)]-yedgesbg10[0:len(yedgesbg10)-1])/2yedgesbg_up11 = yedgesbg11[0:len(yedgesbg11)-1]+(yedgesbg11[1:len(yedgesbg11)]-yedgesbg11[0:len(yedgesbg11)-1])/2yedgesbg_up12 = yedgesbg12[0:len(yedgesbg12)-1]+(yedgesbg12[1:len(yedgesbg12)]-yedgesbg12[0:len(yedgesbg12)-1])/2yedgesbg_up13 = yedgesbg13[0:len(yedgesbg13)-1]+(yedgesbg13[1:len(yedgesbg13)]-yedgesbg13[0:len(yedgesbg13)-1])/2yedgesbg_up14 = yedgesbg14[0:len(yedgesbg14)-1]+(yedgesbg14[1:len(yedgesbg14)]-yedgesbg14[0:len(yedgesbg14)-1])/2yedgesbg_up15 = yedgesbg15[0:len(yedgesbg15)-1]+(yedgesbg15[1:len(yedgesbg15)]-yedgesbg15[0:len(yedgesbg15)-1])/2yedgesbg_up16 = yedgesbg16[0:len(yedgesbg16)-1]+(yedgesbg16[1:len(yedgesbg16)]-yedgesbg16[0:len(yedgesbg16)-1])/2yedgesbg_up17 = yedgesbg17[0:len(yedgesbg17)-1]+(yedgesbg17[1:len(yedgesbg17)]-yedgesbg17[0:len(yedgesbg17)-1])/2vbg9j = np.einsum('ij,i',Hbg9,yedgesbg_up9)vbg10j = np.einsum('ij,i',Hbg10,yedgesbg_up10)vbg11j = np.einsum('ij,i',Hbg11,yedgesbg_up11)vbg12j = np.einsum('ij,i',Hbg12,yedgesbg_up12)vbg13j = np.einsum('ij,i',Hbg13,yedgesbg_up13)vbg14j = np.einsum('ij,i',Hbg14,yedgesbg_up14)vbg15j = np.einsum('ij,i',Hbg15,yedgesbg_up15)vbg16j = np.einsum('ij,i',Hbg16,yedgesbg_up16)vbg17j = np.einsum('ij,i',Hbg17,yedgesbg_up17)Vbg9j = vbg9j/sum(vbg9j)*100Vbg10j = vbg10j/sum(vbg10j)*100Vbg11j = vbg11j/sum(vbg11j)*100Vbg12j = vbg12j/sum(vbg12j)*100Vbg13j = vbg13j/sum(vbg13j)*100Vbg14j = vbg14j/sum(vbg14j)*100Vbg15j = vbg15j/sum(vbg15j)*100Vbg16j = vbg16j/sum(vbg16j)*100Vbg17j = vbg17j/sum(vbg17j)*100x_bg9 = xedgesbg9[0:len(xedgesbg9)-1]+(xedgesbg9[1:len(xedgesbg9)]-xedgesbg9[0:len(xedgesbg9)-1])/2x_bg10 = xedgesbg10[0:len(xedgesbg10)-1]+(xedgesbg10[1:len(xedgesbg10)]-xedgesbg10[0:len(xedgesbg10)-1])/2x_bg11 = xedgesbg11[0:len(xedgesbg11)-1]+(xedgesbg11[1:len(xedgesbg11)]-xedgesbg11[0:len(xedgesbg11)-1])/2x_bg12 = xedgesbg12[0:len(xedgesbg12)-1]+(xedgesbg12[1:len(xedgesbg12)]-xedgesbg12[0:len(xedgesbg12)-1])/2x_bg13 = xedgesbg13[0:len(xedgesbg13)-1]+(xedgesbg13[1:len(xedgesbg13)]-xedgesbg13[0:len(xedgesbg13)-1])/2x_bg14 = xedgesbg14[0:len(xedgesbg14)-1]+(xedgesbg14[1:len(xedgesbg14)]-xedgesbg14[0:len(xedgesbg14)-1])/2x_bg15 = xedgesbg15[0:len(xedgesbg15)-1]+(xedgesbg15[1:len(xedgesbg15)]-xedgesbg15[0:len(xedgesbg15)-1])/2x_bg16 = xedgesbg16[0:len(xedgesbg16)-1]+(xedgesbg16[1:len(xedgesbg16)]-xedgesbg16[0:len(xedgesbg16)-1])/2x_bg17 = xedgesbg17[0:len(xedgesbg17)-1]+(xedgesbg17[1:len(xedgesbg17)]-xedgesbg17[0:len(xedgesbg17)-1])/2

# %%
import numpy as npimport matplotlib.pyplot as pltfrom matplotlib import rcplt.xlim([3.24,3.26])plt.plot(x_bg9,Vbg9j,'r-.',linewidth=3.5, label = 'Isotropic')plt.plot(x_bg10,Vbg10j,'r',linewidth=3.5, label = '[000]')plt.plot(x_bg11,Vbg11j,'g',linewidth=3.5, label = '[111]')plt.plot(x_bg12,Vbg12j,'b',linewidth=3.5, label = 'Radial')plt.plot(x_bg13,Vbg13j,'b-.',linewidth=3.5, label = 'Random')plt.legend(labelspacing = 1.0,loc=1,prop={'size':16})#Custom PlotLabels for differing fontsize in same xlabel#plt.rc('text',usetex=True)#plt.text(2.2,-.5,'$\sigma_{jj}$',fontsize=30)#plt.text(2.5,-.5,'[$\,\,10^{-10}\, \mathrm{N}/\mathrm{nm}^2$]',fontsize = 20)###all four of the of these plots are 25 nm total diameter, 15 nm core diameterplt.xlabel('$\delta E \, [\mathrm{eV}]$',fontsize = 20)plt.tick_params(axis='both', which='major', labelsize=22)tick_vals = np.linspace(0,10,6)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = ''tick_labels[1] = '2'tick_labels[2] = '4'tick_labels[3] = '6'tick_labels[4] = '8'tick_labels[5] = '10'plt.yticks(tick_vals, tick_labels)tick_vals = np.linspace(3.24,3.26,5)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = '+0.04'tick_labels[1] = ''tick_labels[2] = '+0.05'tick_labels[3] = ''tick_labels[4] = '+0.06'plt.xticks(tick_vals, tick_labels)plt.ylabel('Shell volume fraction [$\%$]',fontsize =20)plt.savefig("/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph_core.svg",format='svg',dpi=1200)plt.show()

# %%
import numpy as npimport matplotlib.pyplot as pltfrom matplotlib import rcplt.xlim([3.235,3.265])plt.plot(x_bg14,Vbg14j,'r-.',linewidth=3.5, label = '[000]')plt.plot(x_bg15,Vbg15j,'r',linewidth=3.5, label = '[111]')plt.plot(x_bg16,Vbg16j,'g',linewidth=3.5, label = 'Radial')plt.plot(x_bg17,Vbg17j,'b',linewidth=3.5, label = 'Random')plt.legend(labelspacing = 1.0,loc=1,prop={'size':16})#Custom PlotLabels for differing fontsize in same xlabel#plt.rc('text',usetex=True)#plt.text(2.2,-.5,'$\sigma_{jj}$',fontsize=30)#plt.text(2.5,-.5,'[$\,\,10^{-10}\, \mathrm{N}/\mathrm{nm}^2$]',fontsize = 20)###all four of the of these plots are 25 nm total diameter, 15 nm core diameterplt.xlabel('$\delta E \, [\mathrm{eV}]$',fontsize = 20)plt.tick_params(axis='both', which='major', labelsize=22)tick_vals = np.linspace(0,12,7)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = ''tick_labels[1] = ''tick_labels[2] = '4'tick_labels[3] = ''tick_labels[4] = '8'tick_labels[5] = ''tick_labels[6] = '12'plt.yticks(tick_vals, tick_labels)tick_vals = np.linspace(3.235,3.265,7)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = ' 'tick_labels[1] = '+0.04'tick_labels[2] = ''tick_labels[3] = '+0.05'tick_labels[4] = ''tick_labels[5] = '+0.06'tick_labels[6] = ''plt.xticks(tick_vals, tick_labels)plt.ylabel('Shell volume fraction [$\%$]',fontsize =20)plt.savefig("/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph_Fcore.svg",format='svg',dpi=1200)plt.show()

# %%
#run a bash script here with the following# subprocess.call(' inkscape --export-png=/home/john/newfile.png /home/john/file.svg')#this will vectorize the file.# Thanks to http://neuroscience.telenczuk.pl/?p=331 [Baros Telenczuk]import subprocesssubprocess.call('inkscape --export-png=/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph_core.png /home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph_core.svg',shell=True)subprocess.call('inkscape --export-png=/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph_Fcore.png /home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph_Fcore.svg',shell=True)
# Out:
# 0

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)ax1.plot(x, y)ax1.set_title('Sharing Y axis')ax2.scatter(x, y)

# %%
import matplotlib.pyplot as pltimport matplotlib.image as mpimgimport numpy as npf, (ax1, ax2) = plt.subplots(1, 2, sharey=True)img1 = mpimg.imread('/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph_core.png')img2 = mpimg.imread('/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph_Fcore.png')ax1.imshow(img1)ax1.set_axis_off()ax2.imshow(img2)ax2.set_axis_off()plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0,             hspace = .1, wspace = .1)plt.margins(0,0)plt.tight_layoutplt.savefig("/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_cores.svg",format='svg',dpi=600)plt.show()

# %%
tick_vals = np.linspace(3.0192,3.0202,4)

# %%
tick_vals
# Out:
# array([ 3.0192    ,  3.01953333,  3.01986667,  3.0202    ])

# %%
#run a bash script here with the following# subprocess.call(' inkscape --export-png=/home/john/newfile.png /home/john/file.svg')#this will vectorize the file.# Thanks to http://neuroscience.telenczuk.pl/?p=331 [Baros Telenczuk]import subprocesssubprocess.call('inkscape --export-png=/home/john/projects/calculations/core_shell/microstructure_Zn_ZnO_Eg_hist_sph.png /home/john/projects/calculations/core_shell/microstructure_Zn_ZnO_Eg_hist_sph.svg',shell=True)subprocess.call('inkscape --export-png=/home/john/projects/calculations/core_shell/microstructure_Zn_ZnO_Eg_hist_fac.png /home/john/projects/calculations/core_shell/microstructure_Zn_ZnO_Eg_hist_fac.svg',shell=True)subprocess.call('inkscape --export-png=/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph.png /home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_sph.svg',shell=True)subprocess.call('inkscape --export-png=/home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_fac.png /home/john/projects/calculations/core_shell/microstructure_ZnO_rTiO2_Eg_hist_fac.svg',shell=True)
