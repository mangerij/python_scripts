# %%
# We're going to run MOOSE in a loop for all of the different Euler angles to exploit the maximum phase # difference that will give the maximum band gap splitting# Ideally, we will want to plot the variance of our bandgap distributions as a function of the two euler anglesimport osimport subprocessimport numpy as npos.chdir('/home/john/projects/ferret/')# tensor_mechanics does a Z1 X2 Z3 rotation, we can achieve all of the useful combinations of rotations by just modifying # the 2 and 3 euler angleseuler_2_vec = np.linspace(0,180,40)  euler_3_vec = np.linspace(0,180,40)  for j in range(0,40):    for k in range(0,40):          # Define the base file we will be iteratively modifiying #        infile = open('/home/john/projects/ferret/Zn_ZnO_eulerMismatch_xstl_shell_def.i')        # Open the out file we will be writing at each step in the iteration #        outfile = open('/home/john/projects/ferret/newZn_ZnO_eulerMismatch_xstl_shell-'+repr(j)+'-'+repr(k)+'.i', 'w')        # Note that we are using -'+repr(t)+'.i' in order to for loop the path name. This is used again in the next line.        replacements = {'euler_angle_2 = default':'euler_angle_2 = %s' % euler_2_vec[j],'euler_angle_3 = default':'euler_angle_3 = %s' % euler_3_vec[k],'file_base = out_Zn_ZnO_eulerMismatch_xstl_shell':'file_base = out_Zn_ZnO_eulerMismatch_xstl_shell-'+repr(j)+'-'+repr(k)}        for line in infile:            for src, target in replacements.iteritems():                line = line.replace(src, target)            outfile.write(line)        infile.close()        outfile.close()

# %%
#MOOSE related stuff ran through script on HORNET:# The below code will harvest the finite-element data using ParaView's excellent filtration options. Here we basically use the volume filter. # MOOSE can probably do it but we'll just use ParaView for now.# a new thing to note. Gnome has a hard time handling folders with a large amount of files. We essentially have 625x120 ~ 75,000 so we need to# iteratively load them. This is very similar to needing to use iter_txt as well. # We load in batches of 25x120, which is much more manageable for this computer.import osimport subprocessos.chdir('/home/john/projects/ParaView-bin/bin/')subprocess.call('pvpython /home/john/projects/scripts/MeshEuler-ZnO-1.py',shell=True)subprocess.call('espeak "Your pvpython script is done loading the euler data for part 1"',shell=True)
# Out:
# 0

# %%
os.chdir('/home/john/projects/ParaView-bin/bin/')subprocess.call('pvpython /home/john/projects/scripts/MeshEuler-ZnO-2.py',shell=True)subprocess.call('espeak "Your pvpython script is done loading the euler data for part 2"',shell=True)
# Out:
# 0

# %%
os.chdir('/home/john/projects/ParaView-bin/bin/')subprocess.call('pvpython /home/john/projects/scripts/MeshEuler-ZnO-3.py',shell=True)subprocess.call('espeak "Your pvpython script is done loading the euler data for part 3"',shell=True)
# Out:
# 0

# %%
os.chdir('/home/john/projects/ParaView-bin/bin/')subprocess.call('pvpython /home/john/projects/scripts/MeshEuler-ZnO-4.py',shell=True)subprocess.call('espeak "Your pvpython script is done loading the euler data for part 4"',shell=True)
# Out:
# 0

# %%
os.chdir('/home/john/projects/ParaView-bin/bin/')subprocess.call('pvpython /home/john/projects/scripts/MeshEuler-ZnO-5.py',shell=True)subprocess.call('espeak "Your pvpython script is done loading the euler data for part 5"',shell=True)
# Out:
# 0

# %%
# now loop this 25x12 times to get the comp files. We have 5 partitions in the data since we use 25/5# MeshData-k-j-numfor k in range(0,6):    for j in range(0,25):        fout=open("/home/john/projects/calculations/core_shell/ZnO-eulercsv1/MeshData-"+repr(k)+"-"+repr(j)+"COMP.csv","a")        for num in range(0,12): #MeshData has 12 csv            f = open("/home/john/projects/calculations/core_shell/ZnO-eulercsv1/MeshData-"+repr(k)+"-"+repr(j)+"-"+str(num)+".csv")            f.next() # skip the header            for line in f:                fout.write(line)            f.close()        fout.close()for k in range(6,11):    for j in range(0,25):        fout=open("/home/john/projects/calculations/core_shell/ZnO-eulercsv2/MeshData-"+repr(k)+"-"+repr(j)+"COMP.csv","a")        for num in range(0,12):            f = open("/home/john/projects/calculations/core_shell/ZnO-eulercsv2/MeshData-"+repr(k)+"-"+repr(j)+"-"+str(num)+".csv")            f.next() # skip the header            for line in f:                fout.write(line)            f.close()        fout.close()                for k in range(11,16):    for j in range(0,25):        fout=open("/home/john/projects/calculations/core_shell/ZnO-eulercsv3/MeshData-"+repr(k)+"-"+repr(j)+"COMP.csv","a")        for num in range(0,12):            f = open("/home/john/projects/calculations/core_shell/ZnO-eulercsv3/MeshData-"+repr(k)+"-"+repr(j)+"-"+str(num)+".csv")            f.next() # skip the header            for line in f:                fout.write(line)            f.close()        fout.close()        for k in range(16,21):    for j in range(0,25):        fout=open("/home/john/projects/calculations/core_shell/ZnO-eulercsv4/MeshData-"+repr(k)+"-"+repr(j)+"COMP.csv","a")        for num in range(0,12):            f = open("/home/john/projects/calculations/core_shell/ZnO-eulercsv4/MeshData-"+repr(k)+"-"+repr(j)+"-"+str(num)+".csv")            f.next() # skip the header            for line in f:                fout.write(line)            f.close()        fout.close()        for k in range(21,25):    for j in range(0,25):        fout=open("/home/john/projects/calculations/core_shell/ZnO-eulercsv5/MeshData-"+repr(k)+"-"+repr(j)+"COMP.csv","a")        for num in range(0,12):            f = open("/home/john/projects/calculations/core_shell/ZnO-eulercsv5/MeshData-"+repr(k)+"-"+repr(j)+"-"+str(num)+".csv")            f.next() # skip the header            for line in f:                fout.write(line)            f.close()        fout.close()

# %%
# numpy genfromtxt crashes when loading large files, have to use an iterative loading scheme# Found on stackexchange with some interesting plots on memory. We are essentially using this sceme above with the pvpython scriptsimport numpy as npdef iter_loadtxt(filename, delimiter=',', skiprows=1, dtype=float):    def iter_func():        with open(filename, 'r') as infile:            for _ in range(skiprows):                next(infile)            for line in infile:                line = line.rstrip().split(delimiter)                for item in line:                    yield dtype(item)        iter_loadtxt.rowlength = len(line)    data = np.fromiter(iter_func(), dtype=dtype)    data = data.reshape((-1, iter_loadtxt.rowlength))    return data

# %%
# Scratch all the above like four sentences. While it is true, this computer has a finite amount of ram, we have to be careful with how we approach this# at all steps in the loading process. We can't iteratively load all 625 sets of data and store them in memory, but we can iteratively load one set, # save what we want, clear the rest, and then continue.import numpy as npimport matplotlib.pyplot as pltimport pylabfrom matplotlib import rcimport osimport subprocessfileset_data1 = {}for k in range(0,6):    for j in range(0,25):        fileset_data1[k,j] = iter_loadtxt('/home/john/projects/calculations/core_shell/ZnO-eulercsv1/MeshData-'+repr(k)+'-'+repr(j)+'COMP.csv',delimiter=',',skiprows=1,dtype=float)            euler_2_vec = np.linspace(0,180,25); euler_3_vec = np.linspace(0,180,25);nbins = 250varSxx = np.zeros((25,25)); varSyy = np.zeros((25,25)); varSzz = np.zeros((25,25)); varEg = np.zeros((25,25));vol1 = {}; Sxx1 = {}; Syy1 = {}; Szz1 = {}; HSxx1 = {}; Eg1 = {}; xedgesSxx1 = {}; yedgesSxx1 = {}; yedgesSxx_up1 = {};xedgesSxx_up1 = {}; vSxxj1 = {}; VSxxj1 = {}; xSxx1 = {}; for k in range(0,6):    for j in range(0,25):        #vol1[k,j] = [row[7] for row in fileset_data1[k,j]]        #Sxx1[k,j] = [row[0] for row in fileset_data1[k,j]]        #Syy1[k,j] = [row[1] for row in fileset_data1[k,j]]        #Szz1[k,j] = [row[2] for row in fileset_data1[k,j]]        Eg1[k,j] = [row[3] for row in fileset_data1[k,j]]        #HSxx1[k,j], xedgesSxx1[k,j], yedgesSxx1[k,j] = np.histogram2d(Sxx1[k,j][1:len(Sxx1[k,j])],vol1[k,j][1:len(vol1[k,j])],bins=nbins)         #HSxx1[k,j] = np.rot90(HSxx1[k,j])        #HSxx1[k,j] = np.flipud(HSxx1[k,j])        #yedgesSxx_up1[k,j] = yedgesSxx1[k,j][0:len(yedgesSxx1[k,j])-1]+(yedgesSxx1[k,j][1:len(yedgesSxx1[k,j])]-yedgesSxx1[k,j][0:len(yedgesSxx1[k,j])-1])/2        #vSxxj1[k,j] = np.einsum('ij,i',HSxx1[k,j],yedgesSxx_up1[k,j])        #VSxxj1[k,j] = vSxxj1[k,j]/sum(vSxxj1[k,j])*100        #xSxx1[k,j] = xedgesSxx1[k,j][0:len(xedgesSxx1[k,j])-1]+(xedgesSxx1[k,j][1:len(xedgesSxx1[k,j])]-xedgesSxx1[k,j][0:len(xedgesSxx1[k,j])-1])/2        #varSxx[k,j] = np.var(Sxx1[k,j])        #varSyy[k,j] = np.var(Syy1[k,j])        #varSzz[k,j] = np.var(Szz1[k,j])        varEg[k,j] = np.var(Eg1[k,j])%xdel fileset_data1 #%xdel Sxx1#%xdel Syy1#%xdel Szz1%xdel Eg1subprocess.call('espeak "Loading is complete."',shell=True)
# Out:
# 0

# %%
fileset_data2 = {}for k in range(6,11):    for j in range(0,25):        fileset_data2[k,j] = iter_loadtxt('/home/john/projects/calculations/core_shell/ZnO-eulercsv2/MeshData-'+repr(k)+'-'+repr(j)+'COMP.csv',delimiter=',',skiprows=1,dtype=float)vol2 = {}; Sxx2 = {}; Syy2 = {}; Szz2 = {}; HSxx2 = {}; xedgesSxx2 = {}; yedgesSxx2 = {}; yedgesSxx_up2 = {};xedgesSxx_up2 = {}; vSxxj2 = {}; VSxxj2 = {}; xSxx2 = {}; Eg2 = {};for k in range(6,11):    for j in range(0,25):        #vol2[k,j] = [row[7] for row in fileset_data2[k,j]]        #Sxx2[k,j] = [row[0] for row in fileset_data2[k,j]]        #Syy2[k,j] = [row[1] for row in fileset_data2[k,j]]        #Szz2[k,j] = [row[2] for row in fileset_data2[k,j]]        Eg2[k,j]= [row[3] for row in fileset_data2[k,j]]        #HSxx2[k,j], xedgesSxx2[k,j], yedgesSxx2[k,j] = np.histogram2d(Sxx2[k,j][1:len(Sxx2[k,j])],vol2[k,j][1:len(vol2[k,j])],bins=nbins)         #HSxx2[k,j] = np.rot90(HSxx2[k,j])        #HSxx2[k,j] = np.flipud(HSxx2[k,j])        #yedgesSxx_up2[k,j] = yedgesSxx2[k,j][0:len(yedgesSxx2[k,j])-1]+(yedgesSxx2[k,j][1:len(yedgesSxx2[k,j])]-yedgesSxx2[k,j][0:len(yedgesSxx2[k,j])-1])/2        #vSxxj2[k,j] = np.einsum('ij,i',HSxx2[k,j],yedgesSxx_up2[k,j])        #VSxxj2[k,j] = vSxxj2[k,j]/sum(vSxxj2[k,j])*100        #xSxx2[k,j] = xedgesSxx2[k,j][0:len(xedgesSxx2[k,j])-1]+(xedgesSxx2[k,j][1:len(xedgesSxx2[k,j])]-xedgesSxx2[k,j][0:len(xedgesSxx2[k,j])-1])/2        #varSxx[k,j] = np.var(Sxx2[k,j])        #varSyy[k,j] = np.var(Syy2[k,j])        #varSzz[k,j] = np.var(Szz2[k,j])        varEg[k,j] = np.var(Eg2[k,j])%xdel fileset_data2#%xdel Sxx2#%xdel Syy2#%xdel Szz2%xdel Eg2subprocess.call('espeak "Loading is complete."',shell=True)
# Out:
# 0

# %%
fileset_data3 = {}for k in range(11,16):    for j in range(0,25):        fileset_data3[k,j] = iter_loadtxt('/home/john/projects/calculations/core_shell/ZnO-eulercsv3/MeshData-'+repr(k)+'-'+repr(j)+'COMP.csv',delimiter=',',skiprows=1,dtype=float)        vol3 = {}; Sxx3 = {}; Syy3 = {}; Szz3 = {}; HSxx3 = {}; xedgesSxx3 = {}; yedgesSxx3 = {}; yedgesSxx_up3 = {};xedgesSxx_up3 = {}; vSxxj3 = {}; VSxxj3 = {}; xSxx3 = {}; Eg3 = {};for k in range(11,16):    for j in range(0,25):        #vol3[k,j] = [row[7] for row in fileset_data3[k,j]]        #Sxx3[k,j] = [row[0] for row in fileset_data3[k,j]]        #Syy3[k,j] = [row[1] for row in fileset_data3[k,j]]        #Szz3[k,j] = [row[2] for row in fileset_data3[k,j]]        Eg3[k,j] = [row[3] for row in fileset_data3[k,j]]        #HSxx3[k,j], xedgesSxx3[k,j], yedgesSxx3[k,j] = np.histogram2d(Sxx3[k,j][1:len(Sxx3[k,j])],vol3[k,j][1:len(vol3[k,j])],bins=nbins)         #HSxx3[k,j] = np.rot90(HSxx3[k,j])        #HSxx3[k,j] = np.flipud(HSxx3[k,j])        #yedgesSxx_up3[k,j] = yedgesSxx3[k,j][0:len(yedgesSxx3[k,j])-1]+(yedgesSxx3[k,j][1:len(yedgesSxx3[k,j])]-yedgesSxx3[k,j][0:len(yedgesSxx3[k,j])-1])/2        #vSxxj3[k,j] = np.einsum('ij,i',HSxx3[k,j],yedgesSxx_up3[k,j])        #VSxxj3[k,j] = vSxxj3[k,j]/sum(vSxxj3[k,j])*100        #xSxx3[k,j] = xedgesSxx3[k,j][0:len(xedgesSxx3[k,j])-1]+(xedgesSxx3[k,j][1:len(xedgesSxx3[k,j])]-xedgesSxx3[k,j][0:len(xedgesSxx3[k,j])-1])/2        #varSxx[k,j] = np.var(Sxx3[k,j])        #varSyy[k,j] = np.var(Syy3[k,j])        #varSzz[k,j] = np.var(Szz3[k,j])        varEg[k,j] = np.var(Eg3[k,j])        %xdel fileset_data3#%xdel Sxx3#%xdel Syy3#%xdel Szz3%xdel Eg3subprocess.call('espeak "Loading is complete."',shell=True)
# Out:
# 0

# %%
fileset_data4 = {}for k in range(16,21):    for j in range(0,25):        fileset_data4[k,j] = iter_loadtxt('/home/john/projects/calculations/core_shell/ZnO-eulercsv4/MeshData-'+repr(k)+'-'+repr(j)+'COMP.csv',delimiter=',',skiprows=1,dtype=float)vol4 = {}; Sxx4 = {}; Syy4 = {}; Szz4 = {}; HSxx4 = {}; xedgesSxx4 = {}; yedgesSxx4 = {}; yedgesSxx_up4 = {};xedgesSxx_up4 = {}; vSxxj4 = {}; VSxxj4 = {}; xSxx4 = {}; Eg4 = {};for k in range(16,21):    for j in range(0,25):        #vol4[k,j] = [row[7] for row in fileset_data4[k,j]]        #Sxx4[k,j] = [row[0] for row in fileset_data4[k,j]]        #Syy4[k,j] = [row[1] for row in fileset_data4[k,j]]        #Szz4[k,j] = [row[2] for row in fileset_data4[k,j]]        Eg4[k,j] = [row[3] for row in fileset_data4[k,j]]        #HSxx4[k,j], xedgesSxx4[k,j], yedgesSxx4[k,j] = np.histogram2d(Sxx4[k,j][1:len(Sxx4[k,j])],vol4[k,j][1:len(vol4[k,j])],bins=nbins)         #HSxx4[k,j] = np.rot90(HSxx4[k,j])        #HSxx4[k,j] = np.flipud(HSxx4[k,j])        #yedgesSxx_up4[k,j] = yedgesSxx4[k,j][0:len(yedgesSxx4[k,j])-1]+(yedgesSxx4[k,j][1:len(yedgesSxx4[k,j])]-yedgesSxx4[k,j][0:len(yedgesSxx4[k,j])-1])/2        #vSxxj4[k,j] = np.einsum('ij,i',HSxx4[k,j],yedgesSxx_up4[k,j])        #VSxxj4[k,j] = vSxxj4[k,j]/sum(vSxxj4[k,j])*100        #xSxx4[k,j] = xedgesSxx4[k,j][0:len(xedgesSxx4[k,j])-1]+(xedgesSxx4[k,j][1:len(xedgesSxx4[k,j])]-xedgesSxx4[k,j][0:len(xedgesSxx4[k,j])-1])/2        #varSxx[k,j] = np.var(Sxx4[k,j])        #varSyy[k,j] = np.var(Syy4[k,j])        #varSzz[k,j] = np.var(Szz4[k,j])        varEg[k,j] = np.var(Eg4[k,j])%xdel fileset_data4#%xdel Sxx4#%xdel Syy4#%xdel Szz4%xdel Eg4        subprocess.call('espeak "Loading is complete."',shell=True)
# Out:
# 0

# %%
fileset_data5 = {}for k in range(21,25):    for j in range(0,25):        fileset_data5[k,j] = iter_loadtxt('/home/john/projects/calculations/core_shell/ZnO-eulercsv5/MeshData-'+repr(k)+'-'+repr(j)+'COMP.csv',delimiter=',',skiprows=1,dtype=float)vol5 = {}; Sxx5 = {}; Syy5 = {}; Szz5 = {}; HSxx5 = {}; xedgesSxx5 = {}; yedgesSxx5 = {}; yedgesSxx_up5 = {};xedgesSxx_up5 = {}; vSxxj5 = {}; VSxxj5 = {}; xSxx5 = {}; Eg5 = {};for k in range(21,25):    for j in range(0,25):        #vol5[k,j] = [row[7] for row in fileset_data5[k,j]]        #Sxx5[k,j] = [row[0] for row in fileset_data5[k,j]]        #Syy5[k,j] = [row[1] for row in fileset_data5[k,j]]        #Szz5[k,j] = [row[2] for row in fileset_data5[k,j]]        Eg5[k,j] = [row[3] for row in fileset_data5[k,j]]        #HSxx5[k,j], xedgesSxx5[k,j], yedgesSxx5[k,j] = np.histogram2d(Sxx5[k,j][1:len(Sxx5[k,j])],vol5[k,j][1:len(vol5[k,j])],bins=nbins)         #HSxx5[k,j] = np.rot90(HSxx5[k,j])        #HSxx5[k,j] = np.flipud(HSxx5[k,j])        #yedgesSxx_up5[k,j] = yedgesSxx5[k,j][0:len(yedgesSxx5[k,j])-1]+(yedgesSxx5[k,j][1:len(yedgesSxx5[k,j])]-yedgesSxx5[k,j][0:len(yedgesSxx5[k,j])-1])/2        #vSxxj5[k,j] = np.einsum('ij,i',HSxx5[k,j],yedgesSxx_up5[k,j])        #VSxxj5[k,j] = vSxxj5[k,j]/sum(vSxxj5[k,j])*100        #xSxx5[k,j] = xedgesSxx5[k,j][0:len(xedgesSxx5[k,j])-1]+(xedgesSxx5[k,j][1:len(xedgesSxx5[k,j])]-xedgesSxx5[k,j][0:len(xedgesSxx5[k,j])-1])/2        #varSxx[k,j] = np.var(Sxx5[k,j])        #varSyy[k,j] = np.var(Syy5[k,j])        #varSzz[k,j] = np.var(Szz5[k,j])        varEg[k,j] = np.var(Eg5[k,j])%xdel fileset_data5#%xdel Sxx5#%xdel Syy5#%xdel Szz5%xdel Eg5        subprocess.call('espeak "Final loading is complete."',shell=True)
# Out:
# 0

# %%
 # Plot 2D histogram using pcolorplt.pcolormesh(euler_2_vec,euler_3_vec,varSet*np.power(10,5))plt.ylabel('$\phi_3$',fontsize=16)plt.xlabel('$\Phi_2$',fontsize= 16)#%xdel cbar1cbar1 = plt.colorbar()cbar1.ax.set_ylabel('$\mathrm{var}( E_{g}) 10^{-5} \mathrm{eV}$')plt.xlim([0,180])tick_vals = np.linspace(0,180,3)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = '0'tick_labels[1] = '$\pi/2$'tick_labels[2] = '$\pi$'plt.xticks(tick_vals, tick_labels)plt.ylim([0,180])tick_vals = np.linspace(0,180,3)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = '0'tick_labels[1] = '$\pi/2$'tick_labels[2] = '$\pi$'plt.yticks(tick_vals, tick_labels)plt.title('variance of band gap for ZnO shell')plt.savefig("/home/john/projects/varEg_euler_test1.pdf")#plt.show()

# %%
import numpy as npfrom mpl_toolkits.mplot3d import Axes3Dimport matplotlib.pyplot as pltfrom matplotlib import rcfig = plt.figure()ax = fig.add_subplot(111, projection='3d')x = y = euler_2_vecX, Y = np.meshgrid(x, y)zs = varSet*np.power(10,5)Z = zs.reshape(X.shape)ax.plot_surface(X, Y, Z, rstride=1, cstride=1,alpha = 0.4,color='b')ax.set_xlabel('$\phi_2$',fontsize=20)ax.set_ylabel('$\Phi_3$',fontsize=20)ax.set_zlabel('$\mathrm{var}(E_{g}) 10^{-5} \mathrm{eV}$',fontsize=20)plt.xlim([0,180])tick_vals = np.linspace(0,180,3)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = '0'tick_labels[1] = '$\pi/2$'tick_labels[2] = '$\pi$'plt.xticks(tick_vals, tick_labels)plt.ylim([0,180])tick_vals = np.linspace(0,180,3)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = '0'tick_labels[1] = '$\pi/2$'tick_labels[2] = '$\pi$'plt.yticks(tick_vals, tick_labels)plt.show()

# %%
varSet = varEg

# %%
varSet
# Out:
# array([[  3.72041909e-05,   3.72057171e-05,   3.72089349e-05,          3.72129841e-05,   3.72167733e-05,   3.72192941e-05,          3.72198678e-05,   3.72183418e-05,   3.72151265e-05,          3.72110782e-05,   3.72072843e-05,   3.72047646e-05,          3.72041913e-05,   3.72057164e-05,   3.72089358e-05,          3.72129841e-05,   3.72167728e-05,   3.72192941e-05,          3.72198672e-05,   3.72183415e-05,   3.72151270e-05,          3.72110789e-05,   3.72072849e-05,   3.72047642e-05,          3.72041913e-05],       [  3.70634506e-05,   3.70662896e-05,   3.70809175e-05,          3.71060055e-05,   3.71394229e-05,   3.71786641e-05,          3.72212064e-05,   3.72648412e-05,   3.73078146e-05,          3.73488952e-05,   3.73871890e-05,   3.74219635e-05,          3.74524564e-05,   3.74777427e-05,   3.74967707e-05,          3.75085014e-05,   3.75121661e-05,   3.75075332e-05,          3.74951653e-05,   3.74764968e-05,   3.74537775e-05,          3.74297832e-05,   3.74074247e-05,   3.73893024e
# ...

# %%
