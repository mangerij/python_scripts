# %%
#MOOSE related stuff ran through script on HORNET:# The below code will harvest the finite-element data using ParaView's excellent filtration options. Here we basically use the volume filter. # MOOSE can probably do it but we'll just use ParaView for now.import osimport subprocessos.chdir('/home/john/projects/ParaView-bin/bin/')subprocess.call('pvpython /home/john/projects/calculations/core_shell/ZnO/microstructureZnO.py',shell=True)
# Out:
# 0

# %%
# Need 9 different text "mashers" and deleters. We don't want the leftover blank .csvs from lazy ParaView and we want to concatenate all of the nonblank .csvfout=open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_core_iso_shell_P0COMP.csv","a")for num in range(0,1): #iso has 1 csv    f = open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_core_iso_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close() #not really neededfout.close()fout=open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl000_shell_P0COMP.csv","a")for num in range(0,12): #xstl000 has 12 csv    f = open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl000_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl111_shell_P0COMP.csv","a")for num in range(0,12): #xst111 has 12 csv    f = open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl111_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl_90_shell_P0COMP.csv","a")for num in range(0,12): #xst111 has 12 csv    f = open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl_90_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl_grain_shell_radial_P0COMP.csv","a")for num in range(0,12): #xst_grain_rad has 12 csv    f = open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl_grain_shell_radial_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl_grain_shell_random_P0COMP.csv","a")for num in range(0,12): #xst_grain_rand has 12 csv    f = open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl_grain_shell_random_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_Fcore_xstl000_shell_P0COMP.csv","a")for num in range(0,16): #xst000_fcore has 15 csv    f = open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_Fcore_xstl000_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_Fcore_xstl111_shell_P0COMP.csv","a")for num in range(0,16): #xst111_fcore has 12 csv    f = open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_Fcore_xstl111_shell_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_Fcore_xstl_grain_shell_radial_P0COMP.csv","a")for num in range(0,16): #xst111_fcore has 12 csv    f = open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_Fcore_xstl_grain_shell_radial_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()fout=open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_Fcore_xstl_grain_shell_random_P0COMP.csv","a")for num in range(0,16): #xst111_fcore has 12 csv    f = open("/home/john/projects/calculations/core_shell/ZnO/fsetout_Zn_ZnO_xstl000_Fcore_xstl_grain_shell_random_P0-"+str(num)+".csv")    f.next() # skip the header    for line in f:        fout.write(line)    f.close()fout.close()

# %%
#numpy genfromtxt crashes when loading large files, have to use an iterative loading schemeimport numpy as npdef iter_loadtxt(filename, delimiter=',', skiprows=1, dtype=float):    def iter_func():        with open(filename, 'r') as infile:            for _ in range(skiprows):                next(infile)            for line in infile:                line = line.rstrip().split(delimiter)                for item in line:                    yield dtype(item)        iter_loadtxt.rowlength = len(line)    data = np.fromiter(iter_func(), dtype=dtype)    data = data.reshape((-1, iter_loadtxt.rowlength))    return data

# %%
#This code will compare band gap splittings for varying microstructures of the ZnO-TiO2 core-shell system and plot them on the same graph.import numpy as npimport matplotlib.pyplot as pltimport pylabfrom matplotlib import rc#ZnZnO_iso_data_EgVolume = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/microstructures/ZnO/fsetout_Zn_ZnO_xstl000_core_iso_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)ZnZnO_xstl000_core_xstl000_data_EgVolume = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/microstructures/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl000_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_core_xstl111_data_EgVolume = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/microstructures/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl111_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_core_xstl_g_radial_data_EgVolume = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/microstructures/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl_grain_shell_radial_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_core_xstl_g_random_data_EgVolume = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/microstructures/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl_grain_shell_random_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_Fcore_xstl000_data_EgVolume = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/microstructures/ZnO/fsetout_Zn_ZnO_xstl000_Fcore_xstl000_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_Fcore_xstl111_data_EgVolume = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/microstructures/ZnO/fsetout_Zn_ZnO_xstl000_Fcore_xstl111_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_Fcore_xstl_g_radial_data_EgVolume = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/microstructures/ZnO/fsetout_Zn_ZnO_xstl000_Fcore_xstl_grain_shell_radial_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_Fcore_xstl_g_random_data_EgVolume = iter_loadtxt('//media/My Passport/Linux/projects/calculations/core_shell/final_plots/microstructures/ZnO/fsetout_Zn_ZnO_xstl000_Fcore_xstl_grain_shell_random_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)#ZnZnO_xstl000_core_xstl_90_data_EgVolume = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/microstructures/ZnO/fsetout_Zn_ZnO_xstl000_core_xstl_90_shell_P0COMP.csv',delimiter=',',skiprows=1,dtype=float)ZnOrTiO2_xstl000_core_xstl000_data_EgVolume = iter_loadtxt('/media/My Passport/Linux/projects/calculations/core_shell/final_plots/microstructures/rTiO2/fsetout_ZnO_rTiO2_xstl000_core_xstl000_shell_P0COMPb.csv',delimiter=',',skiprows=1,dtype=float)

# %%
#------Load Variables from the csv------##vol0 = [row[12] for row in ZnZnO_iso_data_EgVolume] vol1 = [row[12] for row in ZnZnO_xstl000_core_xstl000_data_EgVolume]Sxx1 = [row[0] for row in ZnZnO_xstl000_core_xstl000_data_EgVolume]Syy1 = [row[1] for row in ZnZnO_xstl000_core_xstl000_data_EgVolume]Szz1 = [row[2] for row in ZnZnO_xstl000_core_xstl000_data_EgVolume]#vol2 = [row[12] for row in ZnZnO_xstl000_core_xstl111_data_EgVolume] #vol3 = [row[12] for row in ZnZnO_xstl000_core_xstl_g_radial_data_EgVolume]#vol4 = [row[12] for row in ZnZnO_xstl000_core_xstl_g_random_data_EgVolume]#vol5 = [row[12] for row in ZnZnO_xstl000_Fcore_xstl000_data_EgVolume] #vol6 = [row[12] for row in ZnZnO_xstl000_Fcore_xstl111_data_EgVolume] #vol7 = [row[12] for row in ZnZnO_xstl000_Fcore_xstl_g_radial_data_EgVolume]#vol8 = [row[12] for row in ZnZnO_xstl000_Fcore_xstl_g_random_data_EgVolume]#vol9 = [row[12] for row in ZnZnO_xstl000_core_xstl_90_data_EgVolume]vol2 = [row[13] for row in ZnOrTiO2_xstl000_core_xstl000_data_EgVolume] Sxx2 = [row[0] for row in ZnOrTiO2_xstl000_core_xstl000_data_EgVolume]Syy2 = [row[1] for row in ZnOrTiO2_xstl000_core_xstl000_data_EgVolume]Szz2 = [row[2] for row in ZnOrTiO2_xstl000_core_xstl000_data_EgVolume]#Eg0 = [row[8] for row in ZnZnO_iso_data_EgVolume] #Eg1 = [row[8] for row in ZnZnO_xstl000_core_xstl000_data_EgVolume] #Eg2 = [row[8] for row in ZnZnO_xstl000_core_xstl111_data_EgVolume] #Eg3 = [row[8] for row in ZnZnO_xstl000_core_xstl_g_radial_data_EgVolume]#Eg4 = [row[8] for row in ZnZnO_xstl000_core_xstl_g_random_data_EgVolume]#Eg5 = [row[8] for row in ZnZnO_xstl000_Fcore_xstl000_data_EgVolume] #Eg6 = [row[8] for row in ZnZnO_xstl000_Fcore_xstl111_data_EgVolume] #Eg7 = [row[8] for row in ZnZnO_xstl000_Fcore_xstl_g_radial_data_EgVolume]#Eg8 = [row[8] for row in ZnZnO_xstl000_Fcore_xstl_g_random_data_EgVolume]#Eg9 = [row[8] for row in ZnZnO_xstl000_core_xstl_90_data_EgVolume]nbins = 120#comment on nbins, if nbins > ideal, then we get "dips" in the spectrum#                  if nbins < ideal, then we get "peaks" in the spectrum#   ideal = ideal(Precision) in microstructures.py fileHSxx1, xedgesSxx1, yedgesSxx1 = np.histogram2d(Sxx1[1:len(Sxx1)],vol1[1:len(vol1)],bins=nbins)HSyy1, xedgesSyy1, yedgesSyy1 = np.histogram2d(Syy1[1:len(Syy1)],vol1[1:len(vol1)],bins=nbins)HSzz1, xedgesSzz1, yedgesSzz1 = np.histogram2d(Szz1[1:len(Szz1)],vol1[1:len(vol1)],bins=nbins)HSxx2, xedgesSxx2, yedgesSxx2 = np.histogram2d(Sxx2[1:len(Sxx2)],vol2[1:len(vol2)],bins=nbins)HSyy2, xedgesSyy2, yedgesSyy2 = np.histogram2d(Syy2[1:len(Syy2)],vol2[1:len(vol2)],bins=nbins)HSzz2, xedgesSzz2, yedgesSzz2 = np.histogram2d(Szz2[1:len(Szz2)],vol2[1:len(vol2)],bins=nbins)#Hbg0, xedgesbg0, yedgesbg0 = np.histogram2d(Eg0[1:len(Eg0)],vol0[1:len(vol0)],bins=nbins-10) #ideal=nbins-10#Hbg1, xedgesbg1, yedgesbg1 = np.histogram2d(Eg1[1:len(Eg1)],vol1[1:len(vol1)],bins=nbins+20)#Hbg2, xedgesbg2, yedgesbg2 = np.histogram2d(Eg2[1:len(Eg2)],vol2[1:len(vol2)],bins=nbins+43) #ideal=nbins+43#Hbg3, xedgesbg3, yedgesbg3 = np.histogram2d(Eg3[1:len(Eg3)],vol3[1:len(vol3)],bins=nbins)#Hbg4, xedgesbg4, yedgesbg4 = np.histogram2d(Eg4[1:len(Eg4)],vol4[1:len(vol4)],bins=nbins)#Hbg5, xedgesbg5, yedgesbg5 = np.histogram2d(Eg5[1:len(Eg5)],vol5[1:len(vol5)],bins=nbins)#Hbg6, xedgesbg6, yedgesbg6 = np.histogram2d(Eg6[1:len(Eg6)],vol6[1:len(vol6)],bins=nbins)#Hbg7, xedgesbg7, yedgesbg7 = np.histogram2d(Eg7[1:len(Eg7)],vol7[1:len(vol7)],bins=nbins)#Hbg8, xedgesbg8, yedgesbg8 = np.histogram2d(Eg8[1:len(Eg8)],vol8[1:len(vol8)],bins=nbins)#Hbg9, xedgesbg9, yedgesbg9 = np.histogram2d(Eg9[1:len(Eg9)],vol9[1:len(vol9)],bins=nbins)HSxx1 = np.rot90(HSxx1); HSyy1 = np.rot90(HSyy1); HSzz1 = np.rot90(HSzz1);HSxx1 = np.flipud(HSxx1); HSyy1 = np.flipud(HSyy1); HSzz1 = np.flipud(HSzz1);HSxx2 = np.rot90(HSxx2); HSyy2 = np.rot90(HSyy2); HSzz2 = np.rot90(HSzz2);HSxx2 = np.flipud(HSxx2); HSyy2 = np.flipud(HSyy2); HSzz2 = np.flipud(HSzz2);#Hbg0 = np.rot90(Hbg0)#Hbg0 = np.flipud(Hbg0)#Hbg1 = np.rot90(Hbg1)#Hbg1 = np.flipud(Hbg1)#Hbg2 = np.rot90(Hbg2)#Hbg2 = np.flipud(Hbg2)#Hbg3 = np.rot90(Hbg3)#Hbg3 = np.flipud(Hbg3)#Hbg4 = np.rot90(Hbg4)#Hbg4 = np.flipud(Hbg4)#Hbg5 = np.rot90(Hbg5)#Hbg5 = np.flipud(Hbg5)#Hbg6 = np.rot90(Hbg6)#Hbg6 = np.flipud(Hbg6)#Hbg7 = np.rot90(Hbg7)#Hbg7 = np.flipud(Hbg7)#Hbg8 = np.rot90(Hbg8)#Hbg8 = np.flipud(Hbg8)#Hbg9 = np.rot90(Hbg9)#Hbg9 = np.flipud(Hbg9)yedgesSxx1_up = yedgesSxx1[0:len(yedgesSxx1)-1]+(yedgesSxx1[1:len(yedgesSxx1)]-yedgesSxx1[0:len(yedgesSxx1)-1])/2yedgesSyy1_up = yedgesSyy1[0:len(yedgesSyy1)-1]+(yedgesSyy1[1:len(yedgesSyy1)]-yedgesSyy1[0:len(yedgesSyy1)-1])/2yedgesSzz1_up = yedgesSzz1[0:len(yedgesSzz1)-1]+(yedgesSzz1[1:len(yedgesSzz1)]-yedgesSzz1[0:len(yedgesSzz1)-1])/2yedgesSxx2_up = yedgesSxx2[0:len(yedgesSxx2)-1]+(yedgesSxx2[1:len(yedgesSxx2)]-yedgesSxx2[0:len(yedgesSxx2)-1])/2yedgesSyy2_up = yedgesSyy2[0:len(yedgesSyy2)-1]+(yedgesSyy2[1:len(yedgesSyy2)]-yedgesSyy2[0:len(yedgesSyy2)-1])/2yedgesSzz2_up = yedgesSzz2[0:len(yedgesSzz2)-1]+(yedgesSzz2[1:len(yedgesSzz2)]-yedgesSzz2[0:len(yedgesSzz2)-1])/2vSxx1j = np.einsum('ij,i',HSxx1,yedgesSxx1_up)vSyy1j = np.einsum('ij,i',HSyy1,yedgesSyy1_up)vSzz1j = np.einsum('ij,i',HSzz1,yedgesSzz1_up)vSxx2j = np.einsum('ij,i',HSxx2,yedgesSxx2_up)vSyy2j = np.einsum('ij,i',HSyy2,yedgesSyy2_up)vSzz2j = np.einsum('ij,i',HSzz2,yedgesSzz2_up)VSxx1j = vSxx1j/sum(vSxx1j)*100VSyy1j = vSyy1j/sum(vSyy1j)*100VSzz1j = vSzz1j/sum(vSzz1j)*100VSxx2j = vSxx2j/sum(vSxx2j)*100VSyy2j = vSyy2j/sum(vSyy2j)*100VSzz2j = vSzz2j/sum(vSzz2j)*100#yedgesbg_up0 = yedgesbg0[0:len(yedgesbg0)-1]+(yedgesbg0[1:len(yedgesbg0)]-yedgesbg0[0:len(yedgesbg0)-1])/2#yedgesbg_up1 = yedgesbg1[0:len(yedgesbg1)-1]+(yedgesbg1[1:len(yedgesbg1)]-yedgesbg1[0:len(yedgesbg1)-1])/2#yedgesbg_up2 = yedgesbg2[0:len(yedgesbg2)-1]+(yedgesbg2[1:len(yedgesbg2)]-yedgesbg2[0:len(yedgesbg2)-1])/2#yedgesbg_up3 = yedgesbg3[0:len(yedgesbg3)-1]+(yedgesbg3[1:len(yedgesbg3)]-yedgesbg3[0:len(yedgesbg3)-1])/2#yedgesbg_up4 = yedgesbg4[0:len(yedgesbg4)-1]+(yedgesbg4[1:len(yedgesbg4)]-yedgesbg4[0:len(yedgesbg4)-1])/2#yedgesbg_up5 = yedgesbg5[0:len(yedgesbg5)-1]+(yedgesbg5[1:len(yedgesbg5)]-yedgesbg5[0:len(yedgesbg5)-1])/2#yedgesbg_up6 = yedgesbg6[0:len(yedgesbg6)-1]+(yedgesbg6[1:len(yedgesbg6)]-yedgesbg6[0:len(yedgesbg6)-1])/2#yedgesbg_up7 = yedgesbg7[0:len(yedgesbg7)-1]+(yedgesbg7[1:len(yedgesbg7)]-yedgesbg7[0:len(yedgesbg7)-1])/2#yedgesbg_up8 = yedgesbg8[0:len(yedgesbg8)-1]+(yedgesbg8[1:len(yedgesbg8)]-yedgesbg8[0:len(yedgesbg8)-1])/2#yedgesbg_up9 = yedgesbg9[0:len(yedgesbg9)-1]+(yedgesbg9[1:len(yedgesbg9)]-yedgesbg9[0:len(yedgesbg9)-1])/2#vbg0j = np.einsum('ij,i',Hbg0,yedgesbg_up0)#vbg1j = np.einsum('ij,i',Hbg1,yedgesbg_up1)#vbg2j = np.einsum('ij,i',Hbg2,yedgesbg_up2)#vbg3j = np.einsum('ij,i',Hbg3,yedgesbg_up3)#vbg4j = np.einsum('ij,i',Hbg4,yedgesbg_up4)#vbg5j = np.einsum('ij,i',Hbg5,yedgesbg_up5)#vbg6j = np.einsum('ij,i',Hbg6,yedgesbg_up6)#vbg7j = np.einsum('ij,i',Hbg7,yedgesbg_up7)#vbg8j = np.einsum('ij,i',Hbg8,yedgesbg_up8)#vbg9j = np.einsum('ij,i',Hbg9,yedgesbg_up9)#Vbg0j = vbg0j/sum(vbg0j)*100#Vbg1j = vbg1j/sum(vbg1j)*100#Vbg2j = vbg2j/sum(vbg2j)*100#Vbg3j = vbg3j/sum(vbg3j)*100#Vbg4j = vbg4j/sum(vbg4j)*100#Vbg5j = vbg5j/sum(vbg5j)*100#Vbg6j = vbg6j/sum(vbg6j)*100#Vbg7j = vbg7j/sum(vbg7j)*100#Vbg8j = vbg8j/sum(vbg8j)*100#Vbg9j = vbg9j/sum(vbg9j)*100x_Sxx1 = xedgesSxx1[0:len(xedgesSxx1)-1]+(xedgesSxx1[1:len(xedgesSxx1)]-xedgesSxx1[0:len(xedgesSxx1)-1])/2x_Syy1 = xedgesSyy1[0:len(xedgesSzz1)-1]+(xedgesSyy1[1:len(xedgesSyy1)]-xedgesSyy1[0:len(xedgesSyy1)-1])/2x_Szz1 = xedgesSzz1[0:len(xedgesSyy1)-1]+(xedgesSzz1[1:len(xedgesSzz1)]-xedgesSzz1[0:len(xedgesSzz1)-1])/2x_Sxx2 = xedgesSxx2[0:len(xedgesSxx2)-1]+(xedgesSxx2[1:len(xedgesSxx2)]-xedgesSxx2[0:len(xedgesSxx2)-1])/2x_Syy2 = xedgesSyy2[0:len(xedgesSzz2)-1]+(xedgesSyy2[1:len(xedgesSyy2)]-xedgesSyy2[0:len(xedgesSyy2)-1])/2x_Szz2 = xedgesSzz2[0:len(xedgesSyy2)-1]+(xedgesSzz2[1:len(xedgesSzz2)]-xedgesSzz2[0:len(xedgesSzz2)-1])/2#x_bg0 = xedgesbg0[0:len(xedgesbg0)-1]+(xedgesbg0[1:len(xedgesbg0)]-xedgesbg0[0:len(xedgesbg0)-1])/2#x_bg1 = xedgesbg1[0:len(xedgesbg1)-1]+(xedgesbg1[1:len(xedgesbg1)]-xedgesbg1[0:len(xedgesbg1)-1])/2#x_bg2 = xedgesbg2[0:len(xedgesbg2)-1]+(xedgesbg2[1:len(xedgesbg2)]-xedgesbg2[0:len(xedgesbg2)-1])/2#x_bg3 = xedgesbg3[0:len(xedgesbg3)-1]+(xedgesbg3[1:len(xedgesbg3)]-xedgesbg3[0:len(xedgesbg3)-1])/2#x_bg4 = xedgesbg4[0:len(xedgesbg4)-1]+(xedgesbg4[1:len(xedgesbg4)]-xedgesbg4[0:len(xedgesbg4)-1])/2#x_bg5 = xedgesbg5[0:len(xedgesbg5)-1]+(xedgesbg5[1:len(xedgesbg5)]-xedgesbg5[0:len(xedgesbg5)-1])/2#x_bg6 = xedgesbg6[0:len(xedgesbg6)-1]+(xedgesbg6[1:len(xedgesbg6)]-xedgesbg6[0:len(xedgesbg6)-1])/2#x_bg7 = xedgesbg7[0:len(xedgesbg7)-1]+(xedgesbg7[1:len(xedgesbg7)]-xedgesbg7[0:len(xedgesbg7)-1])/2#x_bg8 = xedgesbg8[0:len(xedgesbg8)-1]+(xedgesbg8[1:len(xedgesbg8)]-xedgesbg8[0:len(xedgesbg8)-1])/2#x_bg9 = xedgesbg9[0:len(xedgesbg9)-1]+(xedgesbg9[1:len(xedgesbg9)]-xedgesbg9[0:len(xedgesbg9)-1])/2

# %%
plt.plot(x_bg0,Vbg0j,'g',linewidth=1.8, label = 'Isotropic')plt.plot(x_bg1,Vbg1j,'r',linewidth=1.8, label = '[000]')plt.plot(x_bg2,Vbg2j,'b',linewidth=1.8, label = '[111]') plt.plot(x_bg3,Vbg3j,'r--',linewidth=1.8, label = 'Radial')plt.plot(x_bg4,Vbg4j,'b--',linewidth=1.8, label = 'Random')plt.legend(labelspacing = 0.6,loc=1)plt.xlim([3.13,3.16])plt.xlabel('$E_g$ [$\mathrm{eV}$]')plt.ylabel('Shell volume fraction [$\%$]')#plt.title('25 nm total diameter $\mathrm{Zn}-\mathrm{ZnO}$ core-shell particle, $p = 0$')plt.savefig("/home/john/projects/calculations/core_shell/bg_Zn_ZnO.pdf")plt.show()

# %%
plt.plot(x_bg5,Vbg5j,'r',linewidth=1.9, label = '[000]')plt.plot(x_bg6,Vbg6j,'b',linewidth=1.9, label = '[111]')plt.xlim([3.13,3.16])plt.plot(x_bg7,Vbg7j,'g--',linewidth=1.9, label = 'Radial')plt.plot(x_bg8,Vbg8j,'p--',linewidth=1.9, label = 'Random')plt.legend(labelspacing = 0.6,loc=1)plt.xlabel('$E_g$ [$\mathrm{eV}$]', fontsize = 16)plt.ylabel('Shell volume fraction [$\%$]', fontsize = 16)#plt.title('25 nm total diameter Faceted $\mathrm{Zn}-\mathrm{ZnO}$ core-shell particle, $p = 0$')plt.savefig("/home/john/projects/calculations/core_shell/bg_Zn_ZnO_facet.pdf")plt.show()

# %%
import numpy as npfrom mpl_toolkits.mplot3d import Axes3Dimport matplotlib.pyplot as pltfrom matplotlib import rcplt.plot(x_Sxx1*np.power(10,10),VSxx1j,'g',linewidth=3.5, label = '$\sigma_{xx}$')plt.plot(x_Syy1*np.power(10,10),VSyy1j,'r',linewidth=3.5, label = '$\sigma_{yy}$')plt.plot(x_Szz1*np.power(10,10),VSzz1j,'b',linewidth=3.5, label = '$\sigma_{zz}$') plt.legend(labelspacing = 1.0,loc=1,prop={'size':20})#Custom PlotLabels for differing fontsize in same xlabelplt.rc('text',usetex=True)plt.text(2.5,-1,'$\sigma_{jj}$',fontsize=30)plt.text(2.8,-1,'[$\,\,10^{-10}\, \mathrm{N}/\mathrm{nm}^2$]',fontsize = 20)###both of these plots are 25 nm total diameter, 15 nm core diameter#plt.xlabel('$\sigma_{jj}\,\,\,\,\,\,\,$ [$\,\,10^{10} \mathrm{N}/\mathrm{nm}^2$]',fontsize = 30)plt.tick_params(axis='both', which='major', labelsize=20)plt.xlim([1.5,4.2])tick_vals = np.linspace(2,4,3)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = '2'tick_labels[1] = '3'tick_labels[2] = '4'plt.xticks(tick_vals, tick_labels)plt.ylabel('Shell volume fraction [$\%$]',fontsize =20)plt.savefig("/home/john/projects/Zn_ZnO_stress_hist_larger_Resid.pdf")plt.show()

# %%
import numpy as npfrom mpl_toolkits.mplot3d import Axes3Dimport matplotlib.pyplot as pltfrom matplotlib import rc###both of these plots are 25 nm total diameter, 15 nm core diameterplt.plot(x_Sxx2*np.power(10,10),VSxx2j,'g',linewidth=3.5, label = '$\sigma_{xx}$')plt.plot(x_Syy2*np.power(10,10),VSyy2j,'r',linewidth=3.5, label = '$\sigma_{yy}$')plt.plot(x_Szz2*np.power(10,10),VSzz2j,'b',linewidth=3.5, label = '$\sigma_{zz}$') plt.legend(labelspacing = 1.0,loc=1,prop={'size':20})#Custom PlotLabels for differing fontsize in same labelplt.rc('text',usetex=True)plt.text(-3.4,-1,'$\sigma_{jj}$',fontsize=30)plt.text(-3.1,-1,'[$\,\,10^{-10}\, \mathrm{N}/\mathrm{nm}^2$]',fontsize = 20)#plt.xlabel({'$\sigma_{jj}\,\,\,\,\,\,\,$',fontsize=30},{ [$\,\,10^{10} \mathrm{N}/\mathrm{nm}^2$]',fontsize = 30})plt.tick_params(axis='both', which='major', labelsize=20)tick_vals = np.linspace(-4,-2,3)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = '-4'tick_labels[1] = '-3'tick_labels[2] = '-2'plt.xticks(tick_vals, tick_labels)tick_vals = np.linspace(0,9,4)tick_labels = [tick_vals[i] for i in range(len(tick_vals))]tick_labels[0] = '0'tick_labels[1] = '3'tick_labels[2] = '6'tick_labels[3] = '9'plt.yticks(tick_vals, tick_labels)plt.ylabel('Shell volume fraction [$\%$]',fontsize =20)plt.savefig("/home/john/projects/ZnO_rTiO2_stress_hist_larger_Resid.pdf")plt.show()
