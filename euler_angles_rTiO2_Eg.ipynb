# %%
# We're going to run MOOSE in a loop for all of the different Euler angles to exploit the maximum phase 
# difference that will give the maximum band gap splitting
# Ideally, we will want to plot the variance of our bandgap distributions as a function of the two euler angles
import os
import subprocess
import numpy as np

os.chdir('/home/john/projects/ferret/')

# tensor_mechanics does a Z1 X2 Z3 rotation, we can achieve all of the useful combinations of rotations by just modifying 
# the 2 and 3 euler angles

euler_2_vec = np.linspace(0,180,40)  
euler_3_vec = np.linspace(0,180,40)  


for j in range(0,40):
    for k in range(0,40):  
        # Define the base file we will be iteratively modifiying #
        infile = open('/home/john/projects/ferret/ZnO_rTiO2_eulerMismatch_xstl_shell_def.i')
        # Open the out file we will be writing at each step in the iteration #
        outfile = open('/home/john/projects/ferret/newZnO_rTiO2_eulerMismatch_xstl_shell-'+repr(j)+'-'+repr(k)+'.i', 'w')
        # Note that we are using -'+repr(t)+'.i' in order to for loop the path name. This is used again in the next line.
        replacements = {'euler_angle_2 = default':'euler_angle_2 = %s' % euler_2_vec[j],'euler_angle_3 = default':'euler_angle_3 = %s' % euler_3_vec[k],'file_base = out_ZnO_rTiO2_eulerMismatch_xstl_shell':'file_base = out_ZnO_rTiO2_eulerMismatch_xstl_shell-'+repr(j)+'-'+repr(k)}
        for line in infile:
            for src, target in replacements.iteritems():
                line = line.replace(src, target)
            outfile.write(line)
        infile.close()
        outfile.close()

# %%
#MOOSE related stuff ran through script on HORNET:
# The below code will harvest the finite-element data using ParaView's excellent filtration options. Here we basically use the volume filter. 
# MOOSE can probably do it but we'll just use ParaView for now.
# a new thing to note. Gnome has a hard time handling folders with a large amount of files. We essentially have 625x120 ~ 75,000 so we need to
# iteratively load them. This is very similar to needing to use iter_txt as well. 
# We load in batches of 25x120, which is much more manageable for this computer.

import os
import subprocess

os.chdir('/home/john/projects/ParaView-bin/bin/')
subprocess.call('pvpython /home/john/projects/scripts/MeshEuler-rTiO2-1.py',shell=True)
subprocess.call('espeak "Your pvpython script is done loading the euler data for part 1"',shell=True)
# Out:
# 0

# %%
os.chdir('/home/john/projects/ParaView-bin/bin/')
subprocess.call('pvpython /home/john/projects/scripts/MeshEuler-rTiO2-2.py',shell=True)
subprocess.call('espeak "Your pvpython script is done loading the euler data for part 2"',shell=True)
# Out:
# 0

# %%
os.chdir('/home/john/projects/ParaView-bin/bin/')
subprocess.call('pvpython /home/john/projects/scripts/MeshEuler-rTiO2-3.py',shell=True)
subprocess.call('espeak "Your pvpython script is done loading the euler data for part 3"',shell=True)
# Out:
# 0

# %%
os.chdir('/home/john/projects/ParaView-bin/bin/')
subprocess.call('pvpython /home/john/projects/scripts/MeshEuler-rTiO2-4.py',shell=True)
subprocess.call('espeak "Your pvpython script is done loading the euler data for part 4"',shell=True)
# Out:
# 0

# %%
os.chdir('/home/john/projects/ParaView-bin/bin/')
subprocess.call('pvpython /home/john/projects/scripts/MeshEuler-rTiO2-5.py',shell=True)
subprocess.call('espeak "Your pvpython script is done loading the euler data for part 5. Freddy is a moron."',shell=True)
# Out:
# 0

# %%
# now loop this 25x12 times to get the comp files. We have 5 partitions in the data since we use 25/5
# MeshData-k-j-num

for k in range(0,6):
    for j in range(0,25):
        fout=open("/home/john/projects/calculations/core_shell/rTiO2-eulercsv1/MeshData-"+repr(k)+"-"+repr(j)+"COMP.csv","a")
        for num in range(0,12): #MeshData has 12 csv
            f = open("/home/john/projects/calculations/core_shell/rTiO2-eulercsv1/MeshData-"+repr(k)+"-"+repr(j)+"-"+str(num)+".csv")
            f.next() # skip the header
            for line in f:
                fout.write(line)
            f.close()
        fout.close()

for k in range(6,11):
    for j in range(0,25):
        fout=open("/home/john/projects/calculations/core_shell/rTiO2-eulercsv2/MeshData-"+repr(k)+"-"+repr(j)+"COMP.csv","a")
        for num in range(0,12):
            f = open("/home/john/projects/calculations/core_shell/rTiO2-eulercsv2/MeshData-"+repr(k)+"-"+repr(j)+"-"+str(num)+".csv")
            f.next() # skip the header
            for line in f:
                fout.write(line)
            f.close()
        fout.close()
        
        
for k in range(11,16):
    for j in range(0,25):
        fout=open("/home/john/projects/calculations/core_shell/rTiO2-eulercsv3/MeshData-"+repr(k)+"-"+repr(j)+"COMP.csv","a")
        for num in range(0,12):
            f = open("/home/john/projects/calculations/core_shell/rTiO2-eulercsv3/MeshData-"+repr(k)+"-"+repr(j)+"-"+str(num)+".csv")
            f.next() # skip the header
            for line in f:
                fout.write(line)
            f.close()
        fout.close()
        
for k in range(16,21):
    for j in range(0,25):
        fout=open("/home/john/projects/calculations/core_shell/rTiO2-eulercsv4/MeshData-"+repr(k)+"-"+repr(j)+"COMP.csv","a")
        for num in range(0,12):
            f = open("/home/john/projects/calculations/core_shell/rTiO2-eulercsv4/MeshData-"+repr(k)+"-"+repr(j)+"-"+str(num)+".csv")
            f.next() # skip the header
            for line in f:
                fout.write(line)
            f.close()
        fout.close()
        
for k in range(21,25):
    for j in range(0,25):
        fout=open("/home/john/projects/calculations/core_shell/rTiO2-eulercsv5/MeshData-"+repr(k)+"-"+repr(j)+"COMP.csv","a")
        for num in range(0,12):
            f = open("/home/john/projects/calculations/core_shell/rTiO2-eulercsv5/MeshData-"+repr(k)+"-"+repr(j)+"-"+str(num)+".csv")
            f.next() # skip the header
            for line in f:
                fout.write(line)
            f.close()
        fout.close()

# %%
# numpy genfromtxt crashes when loading large files, have to use an iterative loading scheme
# Found on stackexchange with some interesting plots on memory. We are essentially using this sceme above with the pvpython scripts

import numpy as np

def iter_loadtxt(filename, delimiter=',', skiprows=1, dtype=float):
    def iter_func():
        with open(filename, 'r') as infile:
            for _ in range(skiprows):
                next(infile)
            for line in infile:
                line = line.rstrip().split(delimiter)
                for item in line:
                    yield dtype(item)
        iter_loadtxt.rowlength = len(line)

    data = np.fromiter(iter_func(), dtype=dtype)
    data = data.reshape((-1, iter_loadtxt.rowlength))
    return data

# %%
# Scratch all the above like four sentences. While it is true, this computer has a finite amount of ram, we have to be careful with how we approach this
# at all steps in the loading process. We can't iteratively load all 625 sets of data and store them in memory, but we can iteratively load one set, 
# save what we want, clear the rest, and then continue.


import numpy as np
import matplotlib.pyplot as plt
import pylab
from matplotlib import rc
import os
import subprocess

fileset_data1 = {}
for k in range(0,6):
    for j in range(0,25):
        fileset_data1[k,j] = iter_loadtxt('/home/john/projects/calculations/core_shell/rTiO2-eulercsv1/MeshData-'+repr(k)+'-'+repr(j)+'COMP.csv',delimiter=',',skiprows=1,dtype=float)
       
     
euler_2_vec = np.linspace(0,180,25); euler_3_vec = np.linspace(0,180,25);
nbins = 250
varSxx = np.zeros((25,25)); varSyy = np.zeros((25,25)); varSzz = np.zeros((25,25)); varEg = np.zeros((25,25));

vol1 = {}; Sxx1 = {}; Syy1 = {}; Szz1 = {}; HSxx1 = {}; Eg1 = {}; xedgesSxx1 = {}; yedgesSxx1 = {}; yedgesSxx_up1 = {};
xedgesSxx_up1 = {}; vSxxj1 = {}; VSxxj1 = {}; xSxx1 = {}; 

for k in range(0,6):
    for j in range(0,25):
        #vol1[k,j] = [row[7] for row in fileset_data1[k,j]]
        #Sxx1[k,j] = [row[0] for row in fileset_data1[k,j]]
        #Syy1[k,j] = [row[1] for row in fileset_data1[k,j]]
        #Szz1[k,j] = [row[2] for row in fileset_data1[k,j]]
        Eg1[k,j] = [row[3] for row in fileset_data1[k,j]]
        #HSxx1[k,j], xedgesSxx1[k,j], yedgesSxx1[k,j] = np.histogram2d(Sxx1[k,j][1:len(Sxx1[k,j])],vol1[k,j][1:len(vol1[k,j])],bins=nbins) 
        #HSxx1[k,j] = np.rot90(HSxx1[k,j])
        #HSxx1[k,j] = np.flipud(HSxx1[k,j])
        #yedgesSxx_up1[k,j] = yedgesSxx1[k,j][0:len(yedgesSxx1[k,j])-1]+(yedgesSxx1[k,j][1:len(yedgesSxx1[k,j])]-yedgesSxx1[k,j][0:len(yedgesSxx1[k,j])-1])/2
        #vSxxj1[k,j] = np.einsum('ij,i',HSxx1[k,j],yedgesSxx_up1[k,j])
        #VSxxj1[k,j] = vSxxj1[k,j]/sum(vSxxj1[k,j])*100
        #xSxx1[k,j] = xedgesSxx1[k,j][0:len(xedgesSxx1[k,j])-1]+(xedgesSxx1[k,j][1:len(xedgesSxx1[k,j])]-xedgesSxx1[k,j][0:len(xedgesSxx1[k,j])-1])/2
        #varSxx[k,j] = np.var(Sxx1[k,j])
        #varSyy[k,j] = np.var(Syy1[k,j])
        #varSzz[k,j] = np.var(Szz1[k,j])
        varEg[k,j] = np.var(Eg1[k,j])

# %xdel fileset_data1 
#%xdel Sxx1
#%xdel Syy1
#%xdel Szz1
# %xdel Eg1

subprocess.call('espeak "Loading is complete."',shell=True)
# Out:
# 0

# %%
fileset_data2 = {}
for k in range(6,11):
    for j in range(0,25):
        fileset_data2[k,j] = iter_loadtxt('/home/john/projects/calculations/core_shell/rTiO2-eulercsv2/MeshData-'+repr(k)+'-'+repr(j)+'COMP.csv',delimiter=',',skiprows=1,dtype=float)


vol2 = {}; Sxx2 = {}; Syy2 = {}; Szz2 = {}; HSxx2 = {}; xedgesSxx2 = {}; yedgesSxx2 = {}; yedgesSxx_up2 = {};
xedgesSxx_up2 = {}; vSxxj2 = {}; VSxxj2 = {}; xSxx2 = {}; Eg2 = {};

for k in range(6,11):
    for j in range(0,25):
        #vol2[k,j] = [row[7] for row in fileset_data2[k,j]]
        #Sxx2[k,j] = [row[0] for row in fileset_data2[k,j]]
        #Syy2[k,j] = [row[1] for row in fileset_data2[k,j]]
        #Szz2[k,j] = [row[2] for row in fileset_data2[k,j]]
        Eg2[k,j]= [row[3] for row in fileset_data2[k,j]]
        #HSxx2[k,j], xedgesSxx2[k,j], yedgesSxx2[k,j] = np.histogram2d(Sxx2[k,j][1:len(Sxx2[k,j])],vol2[k,j][1:len(vol2[k,j])],bins=nbins) 
        #HSxx2[k,j] = np.rot90(HSxx2[k,j])
        #HSxx2[k,j] = np.flipud(HSxx2[k,j])
        #yedgesSxx_up2[k,j] = yedgesSxx2[k,j][0:len(yedgesSxx2[k,j])-1]+(yedgesSxx2[k,j][1:len(yedgesSxx2[k,j])]-yedgesSxx2[k,j][0:len(yedgesSxx2[k,j])-1])/2
        #vSxxj2[k,j] = np.einsum('ij,i',HSxx2[k,j],yedgesSxx_up2[k,j])
        #VSxxj2[k,j] = vSxxj2[k,j]/sum(vSxxj2[k,j])*100
        #xSxx2[k,j] = xedgesSxx2[k,j][0:len(xedgesSxx2[k,j])-1]+(xedgesSxx2[k,j][1:len(xedgesSxx2[k,j])]-xedgesSxx2[k,j][0:len(xedgesSxx2[k,j])-1])/2
        #varSxx[k,j] = np.var(Sxx2[k,j])
        #varSyy[k,j] = np.var(Syy2[k,j])
        #varSzz[k,j] = np.var(Szz2[k,j])
        varEg[k,j] = np.var(Eg2[k,j])

# %xdel fileset_data2
#%xdel Sxx2
#%xdel Syy2
#%xdel Szz2
# %xdel Eg2

subprocess.call('espeak "Loading is complete."',shell=True)
# Out:
# 0

# %%
fileset_data3 = {}
for k in range(11,16):
    for j in range(0,25):
        fileset_data3[k,j] = iter_loadtxt('/home/john/projects/calculations/core_shell/rTiO2-eulercsv3/MeshData-'+repr(k)+'-'+repr(j)+'COMP.csv',delimiter=',',skiprows=1,dtype=float)
        
vol3 = {}; Sxx3 = {}; Syy3 = {}; Szz3 = {}; HSxx3 = {}; xedgesSxx3 = {}; yedgesSxx3 = {}; yedgesSxx_up3 = {};
xedgesSxx_up3 = {}; vSxxj3 = {}; VSxxj3 = {}; xSxx3 = {}; Eg3 = {};

for k in range(11,16):
    for j in range(0,25):
        #vol3[k,j] = [row[7] for row in fileset_data3[k,j]]
        #Sxx3[k,j] = [row[0] for row in fileset_data3[k,j]]
        #Syy3[k,j] = [row[1] for row in fileset_data3[k,j]]
        #Szz3[k,j] = [row[2] for row in fileset_data3[k,j]]
        Eg3[k,j] = [row[3] for row in fileset_data3[k,j]]
        #HSxx3[k,j], xedgesSxx3[k,j], yedgesSxx3[k,j] = np.histogram2d(Sxx3[k,j][1:len(Sxx3[k,j])],vol3[k,j][1:len(vol3[k,j])],bins=nbins) 
        #HSxx3[k,j] = np.rot90(HSxx3[k,j])
        #HSxx3[k,j] = np.flipud(HSxx3[k,j])
        #yedgesSxx_up3[k,j] = yedgesSxx3[k,j][0:len(yedgesSxx3[k,j])-1]+(yedgesSxx3[k,j][1:len(yedgesSxx3[k,j])]-yedgesSxx3[k,j][0:len(yedgesSxx3[k,j])-1])/2
        #vSxxj3[k,j] = np.einsum('ij,i',HSxx3[k,j],yedgesSxx_up3[k,j])
        #VSxxj3[k,j] = vSxxj3[k,j]/sum(vSxxj3[k,j])*100
        #xSxx3[k,j] = xedgesSxx3[k,j][0:len(xedgesSxx3[k,j])-1]+(xedgesSxx3[k,j][1:len(xedgesSxx3[k,j])]-xedgesSxx3[k,j][0:len(xedgesSxx3[k,j])-1])/2
        #varSxx[k,j] = np.var(Sxx3[k,j])
        #varSyy[k,j] = np.var(Syy3[k,j])
        #varSzz[k,j] = np.var(Szz3[k,j])
        varEg[k,j] = np.var(Eg3[k,j])

        
# %xdel fileset_data3
#%xdel Sxx3
#%xdel Syy3
#%xdel Szz3
# %xdel Eg3

subprocess.call('espeak "Loading is complete."',shell=True)
# Out:
# 0

# %%
fileset_data4 = {}
for k in range(16,21):
    for j in range(0,25):
        fileset_data4[k,j] = iter_loadtxt('/home/john/projects/calculations/core_shell/rTiO2-eulercsv4/MeshData-'+repr(k)+'-'+repr(j)+'COMP.csv',delimiter=',',skiprows=1,dtype=float)

vol4 = {}; Sxx4 = {}; Syy4 = {}; Szz4 = {}; HSxx4 = {}; xedgesSxx4 = {}; yedgesSxx4 = {}; yedgesSxx_up4 = {};
xedgesSxx_up4 = {}; vSxxj4 = {}; VSxxj4 = {}; xSxx4 = {}; Eg4 = {};

for k in range(16,21):
    for j in range(0,25):
        #vol4[k,j] = [row[7] for row in fileset_data4[k,j]]
        #Sxx4[k,j] = [row[0] for row in fileset_data4[k,j]]
        #Syy4[k,j] = [row[1] for row in fileset_data4[k,j]]
        #Szz4[k,j] = [row[2] for row in fileset_data4[k,j]]
        Eg4[k,j] = [row[3] for row in fileset_data4[k,j]]
        #HSxx4[k,j], xedgesSxx4[k,j], yedgesSxx4[k,j] = np.histogram2d(Sxx4[k,j][1:len(Sxx4[k,j])],vol4[k,j][1:len(vol4[k,j])],bins=nbins) 
        #HSxx4[k,j] = np.rot90(HSxx4[k,j])
        #HSxx4[k,j] = np.flipud(HSxx4[k,j])
        #yedgesSxx_up4[k,j] = yedgesSxx4[k,j][0:len(yedgesSxx4[k,j])-1]+(yedgesSxx4[k,j][1:len(yedgesSxx4[k,j])]-yedgesSxx4[k,j][0:len(yedgesSxx4[k,j])-1])/2
        #vSxxj4[k,j] = np.einsum('ij,i',HSxx4[k,j],yedgesSxx_up4[k,j])
        #VSxxj4[k,j] = vSxxj4[k,j]/sum(vSxxj4[k,j])*100
        #xSxx4[k,j] = xedgesSxx4[k,j][0:len(xedgesSxx4[k,j])-1]+(xedgesSxx4[k,j][1:len(xedgesSxx4[k,j])]-xedgesSxx4[k,j][0:len(xedgesSxx4[k,j])-1])/2
        #varSxx[k,j] = np.var(Sxx4[k,j])
        #varSyy[k,j] = np.var(Syy4[k,j])
        #varSzz[k,j] = np.var(Szz4[k,j])
        varEg[k,j] = np.var(Eg4[k,j])


# %xdel fileset_data4
#%xdel Sxx4
#%xdel Syy4
#%xdel Szz4
# %xdel Eg4
        
subprocess.call('espeak "Loading is complete."',shell=True)
# Out:
# 0

# %%
fileset_data5 = {}

for k in range(21,25):
    for j in range(0,25):
        fileset_data5[k,j] = iter_loadtxt('/home/john/projects/calculations/core_shell/rTiO2-eulercsv5/MeshData-'+repr(k)+'-'+repr(j)+'COMP.csv',delimiter=',',skiprows=1,dtype=float)

vol5 = {}; Sxx5 = {}; Syy5 = {}; Szz5 = {}; HSxx5 = {}; xedgesSxx5 = {}; yedgesSxx5 = {}; yedgesSxx_up5 = {};
xedgesSxx_up5 = {}; vSxxj5 = {}; VSxxj5 = {}; xSxx5 = {}; Eg5 = {};

for k in range(21,25):
    for j in range(0,25):
        #vol5[k,j] = [row[7] for row in fileset_data5[k,j]]
        #Sxx5[k,j] = [row[0] for row in fileset_data5[k,j]]
        #Syy5[k,j] = [row[1] for row in fileset_data5[k,j]]
        #Szz5[k,j] = [row[2] for row in fileset_data5[k,j]]
        Eg5[k,j] = [row[3] for row in fileset_data5[k,j]]
        #HSxx5[k,j], xedgesSxx5[k,j], yedgesSxx5[k,j] = np.histogram2d(Sxx5[k,j][1:len(Sxx5[k,j])],vol5[k,j][1:len(vol5[k,j])],bins=nbins) 
        #HSxx5[k,j] = np.rot90(HSxx5[k,j])
        #HSxx5[k,j] = np.flipud(HSxx5[k,j])
        #yedgesSxx_up5[k,j] = yedgesSxx5[k,j][0:len(yedgesSxx5[k,j])-1]+(yedgesSxx5[k,j][1:len(yedgesSxx5[k,j])]-yedgesSxx5[k,j][0:len(yedgesSxx5[k,j])-1])/2
        #vSxxj5[k,j] = np.einsum('ij,i',HSxx5[k,j],yedgesSxx_up5[k,j])
        #VSxxj5[k,j] = vSxxj5[k,j]/sum(vSxxj5[k,j])*100
        #xSxx5[k,j] = xedgesSxx5[k,j][0:len(xedgesSxx5[k,j])-1]+(xedgesSxx5[k,j][1:len(xedgesSxx5[k,j])]-xedgesSxx5[k,j][0:len(xedgesSxx5[k,j])-1])/2
        #varSxx[k,j] = np.var(Sxx5[k,j])
        #varSyy[k,j] = np.var(Syy5[k,j])
        #varSzz[k,j] = np.var(Szz5[k,j])
        varEg[k,j] = np.var(Eg5[k,j])


# %xdel fileset_data5
#%xdel Sxx5
#%xdel Syy5
#%xdel Szz5
# %xdel Eg5
        
subprocess.call('espeak "Final loading is complete."',shell=True)
# Out:
# 0

# %%
 # Plot 2D histogram using pcolor

plt.pcolormesh(euler_2_vec,euler_3_vec,varSet*np.power(10,5))
plt.ylabel('$\phi_3$',fontsize=16)
plt.xlabel('$\Phi_2$',fontsize= 16)
#%xdel cbar1
cbar1 = plt.colorbar()
cbar1.ax.set_ylabel('$\mathrm{var}( E_{g}) 10^{-5} \mathrm{eV}$')
plt.xlim([0,180])
tick_vals = np.linspace(0,180,3)
tick_labels = [tick_vals[i] for i in range(len(tick_vals))]
tick_labels[0] = '0'
tick_labels[1] = '$\pi/2$'
tick_labels[2] = '$\pi$'
plt.xticks(tick_vals, tick_labels)
plt.ylim([0,180])
tick_vals = np.linspace(0,180,3)
tick_labels = [tick_vals[i] for i in range(len(tick_vals))]
tick_labels[0] = '0'
tick_labels[1] = '$\pi/2$'
tick_labels[2] = '$\pi$'
plt.yticks(tick_vals, tick_labels)
plt.title('variance of band gap for rTiO2 shell')
plt.savefig("/home/john/projects/varEg_euler_rTiO2.pdf")
#plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import rc

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = y = euler_2_vec
X, Y = np.meshgrid(x, y)
zs = varSet*np.power(10,5)
Z = zs.reshape(X.shape)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1,alpha = 0.4,color='b')

ax.set_xlabel('$\phi_2$',fontsize=20)
ax.set_ylabel('$\Phi_3$',fontsize=20)
ax.set_zlabel('$\mathrm{var}(E_{g}) 10^{-5} \mathrm{eV}$',fontsize=20)

plt.xlim([0,180])
tick_vals = np.linspace(0,180,3)
tick_labels = [tick_vals[i] for i in range(len(tick_vals))]
tick_labels[0] = '0'
tick_labels[1] = '$\pi/2$'
tick_labels[2] = '$\pi$'
plt.xticks(tick_vals, tick_labels)
plt.ylim([0,180])
tick_vals = np.linspace(0,180,3)
tick_labels = [tick_vals[i] for i in range(len(tick_vals))]
tick_labels[0] = '0'
tick_labels[1] = '$\pi/2$'
tick_labels[2] = '$\pi$'
plt.yticks(tick_vals, tick_labels)

plt.show()

# %%
varEg
# Out:
# array([[  6.88232887e-06,   6.50096651e-06,   5.55684346e-06,
#           4.30031544e-06,   3.04929331e-06,   2.12145011e-06,
#           1.76464831e-06,   2.09228651e-06,   3.03773450e-06,
#           4.34996054e-06,   5.65508655e-06,   6.58096921e-06,
#           6.88232885e-06,   6.50096654e-06,   5.55684345e-06,
#           4.30031545e-06,   3.04929330e-06,   2.12145012e-06,
#           1.76464830e-06,   2.09228650e-06,   3.03773450e-06,
#           4.34996055e-06,   5.65508656e-06,   6.58096922e-06,
#           6.88232884e-06],
#        [  6.91376184e-06,   6.52600306e-06,   5.58557483e-06,
#           4.34167358e-06,   3.10595702e-06,   2.18736740e-06,
#           1.82714949e-06,   2.13725586e-06,   3.05516406e-06,
#           4.33792756e-06,   5.62093318e-06,   6.53857631e-06,
#           6.84614966e-06,   6.48086811e-06,   5.55649549e-06,
#           4.31905953e-06,   3.08594866e-06,   2.17561977e-06,
#           1.83428021e-06,   2.17052821e-06,   3.11315786e-06,
# ...

# %%
varSet = np.array([[  6.88232887e-06,   6.50096651e-06,   5.55684346e-06,
          4.30031544e-06,   3.04929331e-06,   2.12145011e-06,
          1.76464831e-06,   2.09228651e-06,   3.03773450e-06,
          4.34996054e-06,   5.65508655e-06,   6.58096921e-06,
          6.88232885e-06,   6.50096654e-06,   5.55684345e-06,
          4.30031545e-06,   3.04929330e-06,   2.12145012e-06,
          1.76464830e-06,   2.09228650e-06,   3.03773450e-06,
          4.34996055e-06,   5.65508656e-06,   6.58096922e-06,
          6.88232884e-06],
       [  6.91376184e-06,   6.52600306e-06,   5.58557483e-06,
          4.34167358e-06,   3.10595702e-06,   2.18736740e-06,
          1.82714949e-06,   2.13725586e-06,   3.05516406e-06,
          4.33792756e-06,   5.62093318e-06,   6.53857631e-06,
          6.84614966e-06,   6.48086811e-06,   5.55649549e-06,
          4.31905953e-06,   3.08594866e-06,   2.17561977e-06,
          1.83428021e-06,   2.17052821e-06,   3.11315786e-06,
          4.41216799e-06,   5.70231089e-06,   6.62218023e-06,
          6.93033820e-06],
       [  7.02418683e-06,   6.63819301e-06,   5.71791232e-06,
          4.50594050e-06,   3.30143203e-06,   2.39809010e-06,
          2.02486029e-06,   2.28942586e-06,   3.13549387e-06,
          4.33619157e-06,   5.54807566e-06,   6.42321914e-06,
          6.72453751e-06,   6.38671416e-06,   5.51462404e-06,
          4.34338747e-06,   3.18076359e-06,   2.33609683e-06,
          2.04472394e-06,   2.40420993e-06,   3.33821184e-06,
          4.60386715e-06,   5.85499572e-06,   6.75063643e-06,
          7.05881794e-06],
       [  7.21374980e-06,   6.83665141e-06,   5.95017351e-06,
          4.78556784e-06,   3.62462819e-06,   2.74115209e-06,
          2.34761099e-06,   2.54497702e-06,   3.28432026e-06,
          4.36063812e-06,   5.46082069e-06,   6.26373651e-06,
          6.54616266e-06,   6.24274302e-06,   5.44828155e-06,
          4.38232837e-06,   3.33495216e-06,   2.59673024e-06,
          2.38373964e-06,   2.77811097e-06,   3.69926948e-06,
          4.91682240e-06,   6.11086028e-06,   6.96728819e-06,
          7.26816898e-06],
       [  7.48166341e-06,   7.11867827e-06,   6.27547656e-06,
          5.16818669e-06,   4.05811041e-06,   3.19671204e-06,
          2.77778168e-06,   2.89391518e-06,   3.50375176e-06,
          4.42721980e-06,   5.38713046e-06,   6.09557192e-06,
          6.34834629e-06,   6.08265052e-06,   5.38304154e-06,
          4.45040656e-06,   3.55071409e-06,   2.94778512e-06,
          2.83240092e-06,   3.26928314e-06,   4.17547767e-06,
          5.33670826e-06,   6.46280178e-06,   7.26948999e-06,
          7.55607640e-06],
       [  7.82321175e-06,   7.47737988e-06,   6.68230195e-06,
          5.63637612e-06,   4.57902141e-06,   3.73904373e-06,
          3.29132503e-06,   3.31952268e-06,   3.78943437e-06,
          4.54643321e-06,   5.35117316e-06,   5.95234661e-06,
          6.16848406e-06,   5.94166310e-06,   5.34643638e-06,
          4.56292958e-06,   3.82859113e-06,   3.37554399e-06,
          3.36653860e-06,   3.84921362e-06,   4.74022761e-06,
          5.84297382e-06,   6.89713921e-06,   7.64836003e-06,
          7.91496118e-06],
       [  8.22619516e-06,   7.89863397e-06,   7.15227814e-06,
          6.16663944e-06,   5.15922912e-06,   4.33746278e-06,
          3.85872341e-06,   3.79833525e-06,   4.12865979e-06,
          4.71926071e-06,   5.36741021e-06,   5.85872999e-06,
          6.03621051e-06,   5.84841483e-06,   5.36013249e-06,
          4.72946023e-06,   4.16334229e-06,   3.86087353e-06,
          3.95727763e-06,   4.48499499e-06,   5.36183408e-06,
          6.40846370e-06,   7.39219950e-06,   8.08666498e-06,
          8.32958080e-06],
       [  8.66846387e-06,   8.35886670e-06,   7.65843117e-06,
          6.72806411e-06,   5.76461187e-06,   4.95625550e-06,
          4.44532891e-06,   4.30038290e-06,   4.50010780e-06,
          4.93556255e-06,   5.43748435e-06,   5.82588089e-06,
          5.96763186e-06,   5.81822504e-06,   5.43293493e-06,
          4.94781784e-06,   4.53996222e-06,   4.37736301e-06,
          4.57052735e-06,   5.13926855e-06,   6.00338032e-06,
          6.99905915e-06,   7.91769884e-06,   8.55779026e-06,
          8.77556718e-06],
       [  9.11781008e-06,   8.82494242e-06,   8.16517633e-06,
          7.28250877e-06,   6.35525961e-06,   5.55509895e-06,
          5.01223434e-06,   4.79049479e-06,   4.87473920e-06,
          5.17479447e-06,   5.54983721e-06,   5.84962935e-06,
          5.96214876e-06,   5.84908806e-06,   5.55678892e-06,
          5.20088386e-06,   4.93166893e-06,   4.89020482e-06,
          5.16631707e-06,   5.76980568e-06,   6.62262720e-06,
          7.57403395e-06,   8.43541593e-06,   9.02637392e-06,
          9.21965078e-06],
       [  9.53470526e-06,   9.25673633e-06,   8.63073246e-06,
          7.78646955e-06,   6.88688821e-06,   6.09014487e-06,
          5.51741262e-06,   5.22986735e-06,   5.21828973e-06,
          5.40827801e-06,   5.68148908e-06,   5.91135681e-06,
          6.00263865e-06,   5.92178713e-06,   5.70735405e-06,
          5.45772805e-06,   5.30119910e-06,   5.35728901e-06,
          5.69962981e-06,   6.33037968e-06,   7.17336803e-06,
          8.08813685e-06,   8.90182217e-06,   9.45098925e-06,
          9.62211035e-06],
       [  9.87737240e-06,   9.61205218e-06,   9.01179660e-06,
          8.19559981e-06,   7.31458860e-06,   6.51721426e-06,
          5.91858474e-06,   5.57898043e-06,   5.49465006e-06,
          5.60291976e-06,   5.80201259e-06,   5.98215764e-06,
          6.05992808e-06,   6.00489201e-06,   5.84950143e-06,
          5.67913397e-06,   5.60582193e-06,   5.73345945e-06,
          6.12404523e-06,   6.77426592e-06,   7.60926619e-06,
          8.49595105e-06,   9.27288293e-06,   9.78917465e-06,
          9.94170622e-06],
       [  1.01082119e-05,   9.85297681e-06,   9.26972493e-06,
          8.47039356e-06,   7.59868325e-06,   6.79727567e-06,
          6.17833040e-06,   5.80259007e-06,   5.67045774e-06,
          5.72692770e-06,   5.88022936e-06,   6.03054891e-06,
          6.10137008e-06,   6.06389113e-06,   5.94652575e-06,
          5.82636630e-06,   5.80528226e-06,   5.97757325e-06,
          6.39816089e-06,   7.06034946e-06,   7.88995298e-06,
          8.75820020e-06,   9.51059003e-06,   1.00041008e-05,
          1.01424171e-05],
       [  1.02002740e-05,   9.95237617e-06,   9.37697217e-06,
          8.58275448e-06,   7.71072711e-06,   6.90226315e-06,
          6.26975926e-06,   5.87543207e-06,   5.72197318e-06,
          5.75725914e-06,   5.89285519e-06,   6.03227764e-06,
          6.10140717e-06,   6.07194643e-06,   5.97056331e-06,
          5.87088264e-06,   5.87068055e-06,   6.06060833e-06,
          6.49306653e-06,   7.16016954e-06,   7.98779195e-06,
          8.84836410e-06,   9.58958352e-06,   1.00713207e-05,
          1.02002740e-05],
       [  1.01424172e-05,   9.89905671e-06,   9.32221657e-06,
          8.52111080e-06,   7.63901640e-06,   6.82078427e-06,
          6.18239534e-06,   5.78834663e-06,   5.64126316e-06,
          5.68660820e-06,   5.83238444e-06,   5.97899167e-06,
          6.05064915e-06,   6.01886891e-06,   5.91106939e-06,
          5.80215086e-06,   5.79160869e-06,   5.97220121e-06,
          6.39838991e-06,   7.06349804e-06,   7.89305208e-06,
          8.75752428e-06,   9.50183341e-06,   9.98347671e-06,
          1.01082119e-05],
       [  9.94170622e-06,   9.70009298e-06,   9.11262387e-06,
          8.29271839e-06,   7.39096088e-06,   6.56067769e-06,
          5.92490311e-06,   5.55114520e-06,   5.43930728e-06,
          5.52676909e-06,   5.71079425e-06,   5.88225655e-06,
          5.96001359e-06,   5.91514459e-06,   5.77852417e-06,
          5.63092560e-06,   5.57904286e-06,   5.72324586e-06,
          6.12465637e-06,   6.78045972e-06,   7.61570171e-06,
          8.49585710e-06,   9.25794879e-06,   9.75153885e-06,
          9.87737239e-06],
       [  9.62211034e-06,   9.37938785e-06,   8.77235756e-06,
          7.92216755e-06,   6.99167998e-06,   6.14767718e-06,
          5.52371163e-06,   5.19099136e-06,   5.14401374e-06,
          5.30629057e-06,   5.55697480e-06,   5.77092989e-06,
          5.85817073e-06,   5.78943424e-06,   5.60191446e-06,
          5.38669507e-06,   5.26281569e-06,   5.34349677e-06,
          5.70107244e-06,   6.33943072e-06,   7.18332667e-06,
          8.09044259e-06,   8.88481684e-06,   9.40239696e-06,
          9.53470530e-06],
       [  9.21965078e-06,   8.97274413e-06,   8.33760060e-06,
          7.44647532e-06,   6.47915549e-06,   5.62052113e-06,
          5.01781372e-06,   4.74658760e-06,   4.79353529e-06,
          5.06288506e-06,   5.40844562e-06,   5.68255834e-06,
          5.78296426e-06,   5.68024564e-06,   5.42073557e-06,
          5.11004871e-06,   4.88442086e-06,   4.87489968e-06,
          5.16942588e-06,   5.78145032e-06,   6.63589667e-06,
          7.58021528e-06,   8.42060711e-06,   8.97376840e-06,
          9.11781008e-06],
       [  8.77556718e-06,   8.52098729e-06,   7.84977466e-06,
          6.90842169e-06,   5.89765978e-06,   5.02425243e-06,
          4.45167254e-06,   4.26036311e-06,   4.42744440e-06,
          4.83345272e-06,   5.30036821e-06,   5.65177801e-06,
          5.76967581e-06,   5.62445486e-06,   5.27404909e-06,
          4.84245602e-06,   4.48762521e-06,   4.36304930e-06,
          4.57630898e-06,   5.15311246e-06,   6.01916501e-06,
          7.00968060e-06,   7.90855007e-06,   8.50786189e-06,
          8.66846386e-06],
       [  8.32958082e-06,   8.06335495e-06,   7.34914927e-06,
          6.35040771e-06,   5.29167741e-06,   4.40404197e-06,
          3.86873081e-06,   3.77151654e-06,   4.07906938e-06,
          4.64538184e-06,   5.25570553e-06,   5.69957512e-06,
          5.83984784e-06,   5.64622104e-06,   5.18997512e-06,
          4.61670223e-06,   4.10998733e-06,   3.84969317e-06,
          3.96639474e-06,   4.50036026e-06,   5.37878968e-06,
          6.42308930e-06,   7.39093448e-06,   8.04510543e-06,
          8.22619516e-06],
       [  7.91496116e-06,   7.63283670e-06,   6.87055231e-06,
          5.81042217e-06,   4.70198746e-06,   3.80119195e-06,
          3.30735180e-06,   3.31192428e-06,   3.77119602e-06,
          4.51169635e-06,   5.27949237e-06,   5.82662716e-06,
          5.99401161e-06,   5.74959231e-06,   5.17873998e-06,
          4.45080790e-06,   3.77777132e-06,   3.36848173e-06,
          3.37871906e-06,   3.86499063e-06,   4.75668842e-06,
          5.86035378e-06,   6.90443818e-06,   7.61909431e-06,
          7.82321171e-06],
       [  7.55607639e-06,   7.25410764e-06,   6.44163752e-06,
          5.32046734e-06,   4.16408401e-06,   3.25164748e-06,
          2.79958848e-06,   2.90529125e-06,   3.51562897e-06,
          4.43081923e-06,   5.35842254e-06,   6.01245478e-06,
          6.21041755e-06,   5.91705910e-06,   5.23134640e-06,
          4.34698240e-06,   3.50517432e-06,   2.94440808e-06,
          2.84620765e-06,   3.28399606e-06,   4.18984477e-06,
          5.35501786e-06,   6.47739504e-06,   7.25368314e-06,
          7.48166343e-06],
       [  7.26816897e-06,   6.94369986e-06,   6.08313462e-06,
          4.90659315e-06,   3.70805992e-06,   2.78607743e-06,
          2.37185293e-06,   2.56863533e-06,   3.31567217e-06,
          4.39022109e-06,   5.46545067e-06,   6.22049988e-06,
          6.45017404e-06,   6.11449291e-06,   5.32405398e-06,
          4.29529806e-06,   3.29705679e-06,   2.59569069e-06,
          2.39692691e-06,   2.79026382e-06,   3.71040104e-06,
          4.93382632e-06,   6.12925426e-06,   6.96276451e-06,
          7.21374981e-06],
       [  7.05881793e-06,   6.71156815e-06,   5.80999640e-06,
          4.58938988e-06,   3.35870623e-06,   2.43016140e-06,
          2.04598026e-06,   2.31458288e-06,   3.17013411e-06,
          4.37247268e-06,   5.56791137e-06,   6.40771059e-06,
          6.66726042e-06,   6.30067462e-06,   5.42660841e-06,
          4.27998778e-06,   3.15308296e-06,   2.33602454e-06,
          2.05497006e-06,   2.41271018e-06,   3.34559802e-06,
          4.61712832e-06,   5.87198212e-06,   6.75252521e-06,
          7.02418685e-06],
       [  6.93033818e-06,   6.56312899e-06,   5.63249058e-06,
          4.38409720e-06,   3.13503841e-06,   2.20412861e-06,
          1.83947779e-06,   2.15315206e-06,   3.07730267e-06,
          4.36190019e-06,   5.63689042e-06,   6.53583928e-06,
          6.82029386e-06,   6.43799878e-06,   5.51082639e-06,
          4.28547994e-06,   3.07118197e-06,   2.17571273e-06,
          1.83984289e-06,   2.17484686e-06,   3.11678574e-06,
          4.41947578e-06,   5.71252135e-06,   6.62494386e-06,
          6.91376185e-06],
       [  6.88232887e-06,   6.50096652e-06,   5.55684347e-06,
          4.30031544e-06,   3.04929332e-06,   2.12145011e-06,
          1.76464831e-06,   2.09228651e-06,   3.03773451e-06,
          4.34996058e-06,   5.65508657e-06,   6.58096919e-06,
          6.88232888e-06,   6.50096651e-06,   5.55684345e-06,
          4.30031543e-06,   3.04929331e-06,   2.12145012e-06,
          1.76464831e-06,   2.09228650e-06,   3.03773450e-06,
          4.34996056e-06,   5.65508655e-06,   6.58096920e-06,
          6.88232886e-06]]);

# %%
varSet
# Out:
# array([[  6.88232887e-06,   6.50096651e-06,   5.55684346e-06,
#           4.30031544e-06,   3.04929331e-06,   2.12145011e-06,
#           1.76464831e-06,   2.09228651e-06,   3.03773450e-06,
#           4.34996054e-06,   5.65508655e-06,   6.58096921e-06,
#           6.88232885e-06,   6.50096654e-06,   5.55684345e-06,
#           4.30031545e-06,   3.04929330e-06,   2.12145012e-06,
#           1.76464830e-06,   2.09228650e-06,   3.03773450e-06,
#           4.34996055e-06,   5.65508656e-06,   6.58096922e-06,
#           6.88232884e-06],
#        [  6.91376184e-06,   6.52600306e-06,   5.58557483e-06,
#           4.34167358e-06,   3.10595702e-06,   2.18736740e-06,
#           1.82714949e-06,   2.13725586e-06,   3.05516406e-06,
#           4.33792756e-06,   5.62093318e-06,   6.53857631e-06,
#           6.84614966e-06,   6.48086811e-06,   5.55649549e-06,
#           4.31905953e-06,   3.08594866e-06,   2.17561977e-06,
#           1.83428021e-06,   2.17052821e-06,   3.11315786e-06,
# ...
